# %%
import numpy as np
import pandas as pd
from sklearn.metrics import roc_auc_score, mean_squared_error;
from sklearn.model_selection import train_test_split,ShuffleSplit,GridSearchCV;
from fastFM.mcmc import FMClassification, FMRegression;
from sklearn.preprocessing import OneHotEncoder;
from fastFM import als;
from sklearn.feature_extraction.text import CountVectorizer;
import gc;
import pickle;
import random;
import matplotlib.pyplot as plt;
import time;

# %% [markdown]
# Doumentation : http://ibayer.github.io/fastFM/

# %% [markdown]
# ### Model A: Basic model with just userId and movieId

# %%
def encode(df):
    
    '''
    Input : train and test sets
    Output : One hot encoded datasets
    '''
    
    encoder = OneHotEncoder(handle_unknown='ignore').fit(df)
    #trainX = encoder.transform(trainX)
    #testX = encoder.transform(testX)
    
    return encoder

# %%
ratings = np.genfromtxt('./ml-1m/ratings.dat',delimiter="::")
ratings =  pd.DataFrame(ratings)

ratings.columns = ['userId','movieId','rating','timestamp']
ratings = ratings.drop('timestamp', axis=1)
y = ratings['rating'].values
X = ratings.drop('rating', axis=1)

#trainX, testX, trainY, testY = train_test_split(X, y, test_size=0.20, random_state=1234)
#trainX, testX = encode(trainX,testX)

encoder = encode(X)

##fixed
#trainX, testX, trainY, testY = train_test_split(X, y, test_size=0.10, random_state=1234)
trainX = encoder.transform(trainX)
testX = encoder.transform(testX)

cv = ShuffleSplit(n_splits=3, test_size= int(0.2 * trainX.shape[0]), random_state = 2018)


estimator = als.FMRegression()

params = {
'n_iter' : np.arange(10,100,30),
'rank' :  np.arange(2,12,4),
'l2_reg_w': np.logspace(-6, -1, 3),
'l2_reg_V' : np.logspace(-6, -1, 3)
}

###Gridsearch over parameters
regressor = GridSearchCV(estimator=estimator , cv=cv, param_grid=params)
regressor.fit(trainX, trainY)

###get RMSE
mean_squared_error(regressor.predict(testX),testY)**0.5
# Out:
# 0.8771354587448218

# %% [markdown]
# ### Model B : Adding user data, genre, year of movie

# %%
users = pd.read_csv('./ml-1m/users.dat', sep='::', names=['userId', 'gender', 'age', 'occupation', 'zip'], \
                    header=None)
users.head()
# Out:
# /home/som/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#    userId gender  age  occupation    zip
# 0       1      F    1          10  48067
# 1       2      M   56          16  70072
# 2       3      M   25          15  55117
# 3       4      M   45           7  02460
# 4       5      M   25          20  55455

# %%
gc.collect()
# Out:
# 2082

# %%
movies = pd.read_csv('./ml-1m/movies.dat', sep='::', names=['movieId', 'title', 'genres'], header=None)
movies.head()
movies['year'] = movies.title.apply(lambda x : x[-5:-1])

sparse_genres = pd.DataFrame(CountVectorizer().fit_transform(movies.genres\
                                .map(lambda x: x.replace('|', ' '))).todense())

movies = pd.concat([movies[['movieId']], sparse_genres], axis=1) 


ratings = np.genfromtxt('./ml-1m/ratings.dat',delimiter="::")
ratings =  pd.DataFrame(ratings)

ratings.columns = ['userId','movieId','rating','timestamp']
ratings = ratings.drop('timestamp', axis=1)

ratings = pd.merge(pd.merge(ratings, users, on='userId'), movies, on='movieId')


y = ratings['rating'].values
X = ratings.drop('rating', axis=1)

for feature in X.columns:
    _,X[feature] = np.unique(X[feature], return_inverse=True)

trainX, testX, trainY, testY = train_test_split(X, y, test_size=0.20, random_state=1234)
encoder = encode(X)

##fixed
#trainX, testX, trainY, testY = train_test_split(X, y, test_size=0.10, random_state=1234)
trainX = encoder.transform(trainX)
testX = encoder.transform(testX)



cv = ShuffleSplit(n_splits=3, test_size= int(0.2 * trainX.shape[0]), random_state = 2018)
estimator2 = als.FMRegression()

params = {
'n_iter' : np.arange(10,100,30),
'rank' :  np.arange(2,12,4),
'l2_reg_w': np.logspace(-6, -1, 3),
'l2_reg_V' : np.logspace(-6, -1, 3)
}

###Gridsearch over parameters
regressor2 = GridSearchCV(estimator=estimator2 , cv=cv, param_grid=params)
regressor2.fit(trainX, trainY)

###get RMSE
mean_squared_error(regressor2.predict(testX),testY)**0.5
# Out:
# 0.8783405327095336

# %%
pickle.dump(regressor,open("./dump_regressor1","wb"))
pickle.dump(regressor2,open("./dump_regressor2","wb"))

# %%
regressor1 = pickle.load(open("./dump_regressor","rb"))
# Out:
# GridSearchCV(cv=ShuffleSplit(n_splits=3, random_state=2018, test_size=160033, train_size=None),
#        error_score='raise',
#        estimator=FMRegression(init_stdev=0.1, l2_reg=0, l2_reg_V=0.1, l2_reg_w=0.1, n_iter=100,
#        random_state=123, rank=8),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'n_iter': array([10, 40, 70]), 'rank': array([ 2,  6, 10]), 'l2_reg_w': array([1.00000e-06, 3.16228e-04, 1.00000e-01]), 'l2_reg_V': array([1.00000e-06, 3.16228e-04, 1.00000e-01])},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %% [markdown]
# ```
# Factorization Machines have been described as state of the art for many recommendation systems.
#
# Yet, experience has shown these models to suffer from slowtraining and local minima. Use a large(ish) dataset and characterize where FMs are easy to fit and accurate and where they are not.
#
# 1. Start with models that have no side information, and are only user and item ratings.
# Specifically, subsample datasets from small to large, and subsample users/items
# from sparsely-populated to well-populated, and train and test FMs. Where do they
# work the best? Where do they fail? Can you set good rules of thumbs for their
# training and use?
# 2. Next use side information about users or items. Answer the same questions as
# above.
#
# ```

# %% [markdown]
# ### Regressor 1 : No side information

# %%
def load_data_simple(file_):
    
    '''
    Input 
    
        File_ : file name of the ratings file
    
    Output : test - train dfs
    '''

    ratings = np.genfromtxt(file_,delimiter="::")
    ratings =  pd.DataFrame(ratings)
    
    ratings.columns = ['userId','movieId','rating','timestamp']
    ratings = ratings.drop('timestamp', axis=1)
    
    y = ratings['rating'].values
    X = ratings.drop('rating', axis=1)
    
    encoder = encode(X)
    

    
    ##fixed
    trainX, testX, trainY, testY = train_test_split(X, y, test_size=0.10, random_state=1234)
    trainX = encoder.transform(trainX)
    testX = encoder.transform(testX)
    
    return (X.userId.nunique(),X.movieId.nunique()),trainX, testX, trainY, testY

# %% [markdown]
# #### Subsample data from small to large

# %%
#can grid search do this directly?

#train vs test error as data increase? vs a benchmark model, with and without early stopping vs SVD
#time taken to run the model
#Will try all k, epoch hyperspace together 

##FM without early stopping ?



# For the best iteration - check for local optima

#local optima - by sgd vs gd and changing random state?

# %%
def subsample_user_item(fname, sample_by_="All", model_type = "simple"):
    
    '''
    
    Input : trainX, testX, trainY, testY : dfs from the load_Data_Simple function
    
    sample_by_ : 
        All   -   small to large
        Items -   less to many
        Users -   less to many 
    
    '''
    if model_type == "simple":
        cnt,trainX, testX, trainY, testY = load_data_simple(fname)  
    else:
        cnt,trainX, testX, trainY, testY = load_data_side_info(fname[0],fname[1],fname[2]) 
        
    if sample_by_ == "All":
        #cv = ShuffleSplit(n_splits=10, test_size= int(0.2 * trainX.shape[0]), random_state = 2018)
        
        model_run = {}
        #keep lambda at
        _l = trainX.shape[0]
        
        ###10% for cv
        setcv = set(random.sample(range(_l), int(_l * .10)))
        potentialtrain = set(range(_l)) - setcv
        
        for i in np.arange(.2,1.01,0.2):
            #local split 
            settrain = random.sample(potentialtrain, int(len(potentialtrain) * i))
            print("model_" + sample_by_ +"_"+ str(i))
            model_run["model_" + sample_by_ +"_"+ str(i)] = fm_model(setcv,settrain,trainX,testX,trainY,testY)
            gc.collect()
        #return statistics
        return model_run

    if sample_by_ == "Items":
        # number of items in the dataset : 
        nusers = cnt[0]
        nitems = cnt[1]
        ###**modify**
        
        model_run = {}
        #keep lambda at
        _l = trainX.shape[0]
        
        ###10% for cv
        setcv = set(random.sample(range(_l), int(_l * .10)))
        potentialtrain = set(range(_l)) - setcv
        
        
        for i in [1,5,25,125,625,np.inf]:    #i defines atmost # of movies/items to be sampled
            #local split 
            settrain = set()
            #adds additional 1 min per model
            for j in range(nusers,nusers+nitems): #loop through movie columns
            #list(potentialtrain)# too much time to slice
                train_indices = np.argwhere(trainX[:,j])[:,0] #get non-zero indices which are legal 
                
                cand_indices = potentialtrain.intersection(set(train_indices))
                settrain.update(random.sample(cand_indices, min(i,len(cand_indices))))
                
            
            print("CV size",len(setcv)/(len(settrain)+len(setcv)))
            
            print("model_" + sample_by_ +"_"+ str(i))
            model_run["model_" + sample_by_ +"_"+ str(i)] = fm_model(setcv,settrain,trainX,testX,trainY,testY)        
            gc.collect()
        
        return model_run
    
    
    if sample_by_ == "Users":
        # number of items in the dataset : 
        nusers = cnt[0]
        #nitems = cnt[1]
        ###**modify**
        
        model_run = {}
        #keep lambda at
        _l = trainX.shape[0]
        
        ###10% for cv
        setcv = set(random.sample(range(_l), int(_l * .10)))
        potentialtrain = set(range(_l)) - setcv
        
        
        for i in [1,2,4,16,32,np.inf]:    #i defines atmost # of movies/items to be sampled
            #local split 
            settrain = set()
            #adds additional 1 min per model
            for j in range(nusers): #loop through movie columns
            #list(potentialtrain)# too much time to slice
                train_indices = np.argwhere(trainX[:,j])[:,0] #get non-zero indices which are legal 
                
                cand_indices = potentialtrain.intersection(set(train_indices))
                settrain.update(random.sample(cand_indices, min(i,len(cand_indices))))
                

            print("CV size",len(setcv)/(len(settrain)+len(setcv)))
            
            print("model_" + sample_by_ +"_"+ str(i))
            model_run["model_" + sample_by_ +"_"+ str(i)] = fm_model(setcv,settrain,trainX,testX,trainY,testY)        
            gc.collect()
        
        return model_run

# %%
def fm_model(setcv,settrain,trainX,testX,trainY,testY):

    '''
    
    return:
        dict of dict  to store size, time for run, train error, test error etc.
    '''
    
    ##Optimise with cv

    model_summary = {}
    _ = "_"
    
    
    ##Get baseline once
    #https://surprise.readthedocs.io/en/stable/
                #basic_algorithms.html#surprise.prediction_algorithms.baseline_only.BaselineOnly
    
    
    
    itercnt = 0
    ##24 models : hyperspace
    for n_iter in np.arange(50,101,25):
        for rank in  np.arange(2,15,3):
            for l2_reg in np.logspace(-4, 1, 5): 
                ##future plan : further granular level regularization
                    
                start = time.time()
                
                #als : coordinate descent
                estimator_x = als.FMRegression(n_iter = int(n_iter), rank = int(rank), l2_reg = l2_reg)
                estimator_x.fit(trainX[list(settrain)],trainY[list(settrain)])
                
                #estimator_x.fit(trainX[list(settrain)],trainY[list(settrain)])
                
                
                
                ###get RMSE
                train_rmse = mean_squared_error(estimator_x.predict(trainX[list(settrain)]),trainY[list(settrain)])**0.5
                cv_rmse =    mean_squared_error(estimator_x.predict(trainX[list(setcv)]),trainY[list(setcv)])**0.5
                
                #not being used for evaluation *********
                test_rmse = mean_squared_error(estimator_x.predict(testX),testY)**0.5
                
                #average rating of the train set
                baseline = np.mean(trainY[list(settrain)])
                train_baseline = mean_squared_error(np.repeat(baseline,len(testY)),testY)**0.5
                
                #Model summary to be returned for all model
                itercnt += 1
                model_ = {
                'train_rmse' : train_rmse,
                'test_rmse' : test_rmse,
                'cv_rmse' : cv_rmse,
                'train_baseline_rmse' : train_baseline,
                'model_obj' : estimator_x,
                'n_iter' : n_iter,
                'rank' :  rank, #k
                'l2_reg' : l2_reg,
                'train_size':len(settrain),
                #'l2_reg_V':l2_reg_V, #future
                #'l2_reg_w' : l2_reg_w,
                    
                'time' : time.time() - start
                    }
                
                print("\n Model " + str(itercnt) + "done." + "\t CV RMSE: " + str(cv_rmse))
                model_summary["model_seq_ "+str(itercnt) + _ + str(n_iter) +_+ str(rank) +_+ str(l2_reg)] = model_


    
    return model_summary

# %%
gc.collect()
# Out:
# 1204

# %% [markdown]
# #### Subsample data from small to large

# %%
###store function return
#trainX, testX, trainY, testY = load_data_simple('./ml-1m/ratings.dat')
basic_model = subsample_user_item('./ml-1m/ratings.dat')
#pickle object for later use
# Out:
# model_All_0.2
#
#  Model 1done.	 CV RMSE: 2.478559963716515
#
#  Model 2done.	 CV RMSE: 1.485147089217713
#
#  Model 3done.	 CV RMSE: 1.0879465799151953
#
#  Model 4done.	 CV RMSE: 0.9652737012755883
#
#  Model 5done.	 CV RMSE: 2.0180079526330337
#
#  Model 6done.	 CV RMSE: 1.5913491622411378
#
#  Model 7done.	 CV RMSE: 1.2900936026463659
#
#  Model 8done.	 CV RMSE: 1.0302302013398854
#
#  Model 9done.	 CV RMSE: 1.8230058032498637
#
#  Model 10done.	 CV RMSE: 1.6620316042378767
#
#  Model 11done.	 CV RMSE: 1.4481483260207597
#
#  Model 12done.	 CV RMSE: 1.0827463293339732
#
#  Model 13done.	 CV RMSE: 2.7997272069163643
#
#  Model 14done.	 CV RMSE: 1.5683450980617133
#
#  Model 15done.	 CV RMSE: 1.1043621199599958
#
#  Model 16done.	 CV RMSE: 0.9641183216173389
#
#  Model 17done.	 CV RMSE: 2.238196745801011
#
#  Model 18done.	 CV RMSE: 1.7153528520763002
#
#  Model 19done.	 CV RMSE: 1.318828446764848
#
#  Model 20done.	 CV RMSE: 1.0310090537919052
#
#  Model 21done.	 CV RMSE: 1.965771861554259
#
#  Model 22done.	 CV RMSE: 1.7833070775883046
#
#  Model 23done.	 CV RMSE: 1.5000816171798377
#
#  Model 24done.	 CV RMSE: 1.0851040338438478
#
#  Model 25done.	 CV RMSE: 2.8095608152940232
#
#  Model 26done.	 CV RMSE: 1.6896231349010262
#
#  Model 27done.	 CV RMSE: 1.1142857193273863
#
#  Model 28done.	 CV RMSE: 0.9627350809362248
#
#  Model 29done.	 CV RMSE: 2.421802132046065
#
#  Model 30done.	 CV RMSE: 1.8255080355173068
#
#  Model 31done.	 CV RMSE: 1.3313309729482186
#
#  Model 32done.	 CV RMSE: 1.0321641287412548
#
#  Model 33done.	 CV RMSE: 2.084020276968746
#
#  Model 34done.	 CV RMSE: 1.885274615853569
#
#  Model 35done.	 CV RMSE: 1.535498673213737
#
#  Model 36done.	 CV RMSE: 1.085031203451812
# model_All_0.4
#
#  Model 1done.	 CV RMSE: 1.2321268950749868
#
#  Model 2done.	 CV RMSE: 1.0310274057558013
#
#  Model 3done.	 CV RMSE: 0.9581536209177853
#
#  Model 4done.	 CV RMSE: 0.9044024066496245
#
#  Model 5done.	 CV RMSE: 1.3767789989734605
#
#  Model 6done.	 CV RMSE: 1.190730122189868
#
#  Model 7done.	 CV RMSE: 1.056087677982345
#
#  Model 8done.	 CV RMSE: 0.9241233797625041
#
#  Model 9done.	 CV RMSE: 1.4065148870033892
#
#  Model 10done.	 CV RMSE: 1.2716504405268578
#
#  Model 11done.	 CV RMSE: 1.1351853987181717
#
#  Model 12done.	 CV RMSE: 0.9496626324336283
#
#  Model 13done.	 CV RMSE: 1.2946408521881796
#
#  Model 14done.	 CV RMSE: 1.052593845888246
#
#  Model 15done.	 CV RMSE: 0.9606543953945293
#
#  Model 16done.	 CV RMSE: 0.9032472975038075
#
#  Model 17done.	 CV RMSE: 1.521727954189296
#
#  Model 18done.	 CV RMSE: 1.2565687347802412
#
#  Model 19done.	 CV RMSE: 1.067862339468333
#
#  Model 20done.	 CV RMSE: 0.921442182686708
#
#  Model 21done.	 CV RMSE: 1.4901544843908556
#
#  Model 22done.	 CV RMSE: 1.321197689386406
#
#  Model 23done.	 CV RMSE: 1.1423912282666082
#
#  Model 24done.	 CV RMSE: 0.9486873851240649
#
#  Model 25done.	 CV RMSE: 1.3551933064741146
#
#  Model 26done.	 CV RMSE: 1.0619073307267735
#
#  Model 27done.	 CV RMSE: 0.9594806827874329
#
#  Model 28done.	 CV RMSE: 0.9037819102795142
#
#  Model 29done.	 CV RMSE: 1.6348400131302876
#
#  Model 30done.	 CV RMSE: 1.301735086000492
#
#  Model 31done.	 CV RMSE: 1.0669126801527495
#
#  Model 32done.	 CV RMSE: 0.9206148897834636
#
#  Model 33done.	 CV RMSE: 1.5485775739901249
#
#  Model 34done.	 CV RMSE: 1.3724910987852381
#
#  Model 35done.	 CV RMSE: 1.1525561355445066
#
#  Model 36done.	 CV RMSE: 0.9488358930577004
# model_All_0.6000000000000001
#
#  Model 1done.	 CV RMSE: 1.0150955827252472
#
#  Model 2done.	 CV RMSE: 0.9235396778603611
#
#  Model 3done.	 CV RMSE: 0.9040799162695917
#
#  Model 4done.	 CV RMSE: 0.8862721604940058
#
#  Model 5done.	 CV RMSE: 1.0063510381515168
#
#  Model 6done.	 CV RMSE: 0.9806350695523333
#
#  Model 7done.	 CV RMSE: 0.9339210040113227
#
#  Model 8done.	 CV RMSE: 0.8892263294480758
#
#  Model 9done.	 CV RMSE: 1.1099086352116518
#
#  Model 10done.	 CV RMSE: 1.0575425223325818
#
#  Model 11done.	 CV RMSE: 0.9923282811898648
#
#  Model 12done.	 CV RMSE: 0.9036178097958387
#
#  Model 13done.	 CV RMSE: 1.1276210524897174
#
#  Model 14done.	 CV RMSE: 0.9386917485757229
#
#  Model 15done.	 CV RMSE: 0.9052517970739729
#
#  Model 16done.	 CV RMSE: 0.8862067049775142
#
#  Model 17done.	 CV RMSE: 1.0201244256344077
#
#  Model 18done.	 CV RMSE: 0.9932849426736338
#
#  Model 19done.	 CV RMSE: 0.9331398630815068
#
#  Model 20done.	 CV RMSE: 0.8888665512471301
#
#  Model 21done.	 CV RMSE: 1.1486049519199888
#
#  Model 22done.	 CV RMSE: 1.0766304333195817
#
#  Model 23done.	 CV RMSE: 1.001193761753146
#
#  Model 24done.	 CV RMSE: 0.9027401237043537
#
#  Model 25done.	 CV RMSE: 1.2031654574258988
#
#  Model 26done.	 CV RMSE: 0.9469459126162585
#
#  Model 27done.	 CV RMSE: 0.9053380186883264
#
#  Model 28done.	 CV RMSE: 0.8861800869004666
#
#  Model 29done.	 CV RMSE: 1.0363268034116737
#
#  Model 30done.	 CV RMSE: 0.9987464621068441
#
#  Model 31done.	 CV RMSE: 0.9337649794114706
#
#  Model 32done.	 CV RMSE: 0.8887569641310069
#
#  Model 33done.	 CV RMSE: 1.1716270997120133
#
#  Model 34done.	 CV RMSE: 1.0931816805615866
#
#  Model 35done.	 CV RMSE: 1.0079479729612373
#
#  Model 36done.	 CV RMSE: 0.902889578896284
# model_All_0.8
#
#  Model 1done.	 CV RMSE: 0.9148532475783969
#
#  Model 2done.	 CV RMSE: 0.8905964461633518
#
#  Model 3done.	 CV RMSE: 0.8854554425083486
#
#  Model 4done.	 CV RMSE: 0.878056294271867
#
#  Model 5done.	 CV RMSE: 0.9194747030752435
#
#  Model 6done.	 CV RMSE: 0.9129709130338418
#
#  Model 7done.	 CV RMSE: 0.8957016636681916
#
#  Model 8done.	 CV RMSE: 0.8743369233281856
#
#  Model 9done.	 CV RMSE: 0.968061344744867
#
#  Model 10done.	 CV RMSE: 0.9498944500807991
#
#  Model 11done.	 CV RMSE: 0.919688211281634
#
#  Model 12done.	 CV RMSE: 0.8785089804593176
#
#  Model 13done.	 CV RMSE: 0.9400593261222379
#
#  Model 14done.	 CV RMSE: 0.8906185019408128
#
#  Model 15done.	 CV RMSE: 0.8851991984816714
#
#  Model 16done.	 CV RMSE: 0.8780907860948961
#
#  Model 17done.	 CV RMSE: 0.9223517971384422
#
#  Model 18done.	 CV RMSE: 0.9196857267070006
#
#  Model 19done.	 CV RMSE: 0.8980691189936164
#
#  Model 20done.	 CV RMSE: 0.8743782350332143
#
#  Model 21done.	 CV RMSE: 0.9750349648542194
#
#  Model 22done.	 CV RMSE: 0.9565118069296892
#
#  Model 23done.	 CV RMSE: 0.9211903404533522
#
#  Model 24done.	 CV RMSE: 0.8782446954300541
#
#  Model 25done.	 CV RMSE: 0.9286002623778072
#
#  Model 26done.	 CV RMSE: 0.891141004308877
#
#  Model 27done.	 CV RMSE: 0.8853244145767705
#
#  Model 28done.	 CV RMSE: 0.8780891107468569
#
#  Model 29done.	 CV RMSE: 0.9370461445120001
#
#  Model 30done.	 CV RMSE: 0.9269969943492089
#
#  Model 31done.	 CV RMSE: 0.8991866913836096
#
#  Model 32done.	 CV RMSE: 0.8743851337667132
#
#  Model 33done.	 CV RMSE: 0.9824252245157638
#
#  Model 34done.	 CV RMSE: 0.9625322427903946
#
#  Model 35done.	 CV RMSE: 0.9215467393562353
#
#  Model 36done.	 CV RMSE: 0.8781897201684087
# model_All_1.0
#
#  Model 1done.	 CV RMSE: 0.8837538029781621
#
#  Model 2done.	 CV RMSE: 0.88026504397354
#
#  Model 3done.	 CV RMSE: 0.87847020600366
#
#  Model 4done.	 CV RMSE: 0.8735245254635295
#
#  Model 5done.	 CV RMSE: 0.9311811291673128
#
#  Model 6done.	 CV RMSE: 0.9011568905710665
#
#  Model 7done.	 CV RMSE: 0.884262686773545
#
#  Model 8done.	 CV RMSE: 0.8665896958026588
#
#  Model 9done.	 CV RMSE: 0.9194570827793365
#
#  Model 10done.	 CV RMSE: 0.9154635663878227
#
#  Model 11done.	 CV RMSE: 0.8960436159534486
#
#  Model 12done.	 CV RMSE: 0.8662762503698525
#
#  Model 13done.	 CV RMSE: 0.8838512996830623
#
#  Model 14done.	 CV RMSE: 0.8805054461915423
#
#  Model 15done.	 CV RMSE: 0.8784808257999668
#
#  Model 16done.	 CV RMSE: 0.8735063622495722
#
#  Model 17done.	 CV RMSE: 0.9134349739730746
#
#  Model 18done.	 CV RMSE: 0.9036015907447491
#
#  Model 19done.	 CV RMSE: 0.8841182104000967
#
#  Model 20done.	 CV RMSE: 0.8664451623466087
#
#  Model 21done.	 CV RMSE: 0.927914897153705
#
#  Model 22done.	 CV RMSE: 0.9228873845597908
#
#  Model 23done.	 CV RMSE: 0.8949061198373583
#
#  Model 24done.	 CV RMSE: 0.8658934139106308
#
#  Model 25done.	 CV RMSE: 0.8834100170493303
#
#  Model 26done.	 CV RMSE: 0.8806607570804279
#
#  Model 27done.	 CV RMSE: 0.878449785410901
#
#  Model 28done.	 CV RMSE: 0.873497191878166
#
#  Model 29done.	 CV RMSE: 0.9091008414479329
#
#  Model 30done.	 CV RMSE: 0.9015442432352252
#
#  Model 31done.	 CV RMSE: 0.8833635337022266
#
#  Model 32done.	 CV RMSE: 0.8663772286251282
#
#  Model 33done.	 CV RMSE: 0.9373678295919013
#
#  Model 34done.	 CV RMSE: 0.9308070345395144
#
#  Model 35done.	 CV RMSE: 0.8942611780968691
#
#  Model 36done.	 CV RMSE: 0.8656917896423594

# %%
pickle.dump(basic_model,open("./dump_basic_model","wb"))

# %%
#check best RMSE
m = {}
mi = 10.0

for key in basic_model.keys():
    for k2 in basic_model[key].keys():
        if basic_model[key][k2]["cv_rmse"] <= mi:
            mi = basic_model[key][k2]["cv_rmse"]
            m[basic_model[key][k2]["cv_rmse"]] = key+"_"+k2
        
        
print("Best model: ",m[mi],"\t","best cv error",mi)
# Out:
# Best model:  model_All_1.0_model_seq_ 36_100_6_1.0 	 best cv error 0.8656917896423594

# %% [markdown]
# #### Subsample user/items from sparsely populated to well populated

# %% [markdown]
# ##### Items

# %%
#subsample user/items
#Same performance graphs for low number of items to high, same for users.

##- where do they fail? where do they work best?
basic_model_sub_items = subsample_user_item('./ml-1m/ratings.dat','Items')
#basic_model_sub_users = subsample_user_item('./ml-1m/ratings.dat','Users')
# Out:
# CV size 0.9607146287580444
# model_Items_1
#
#  Model 1done.	 CV RMSE: 1.3694701811217187
#
#  Model 2done.	 CV RMSE: 1.320876687383279
#
#  Model 3done.	 CV RMSE: 1.164024502510841
#
#  Model 4done.	 CV RMSE: 1.1112400903834134
#
#  Model 5done.	 CV RMSE: 1.3694278036638885
#
#  Model 6done.	 CV RMSE: 1.320601609877505
#
#  Model 7done.	 CV RMSE: 1.164099796858004
#
#  Model 8done.	 CV RMSE: 1.1110549575926465
#
#  Model 9done.	 CV RMSE: 1.3692149451355689
#
#  Model 10done.	 CV RMSE: 1.3201027201463964
#
#  Model 11done.	 CV RMSE: 1.1640791123431269
#
#  Model 12done.	 CV RMSE: 1.1110065192998009
#
#  Model 13done.	 CV RMSE: 1.367972004425819
#
#  Model 14done.	 CV RMSE: 1.300597213170513
#
#  Model 15done.	 CV RMSE: 1.160631665715515
#
#  Model 16done.	 CV RMSE: 1.1112404406604677
#
#  Model 17done.	 CV RMSE: 1.367860051871458
#
#  Model 18done.	 CV RMSE: 1.3005040077418824
#
#  Model 19done.	 CV RMSE: 1.160688884485152
#
#  Model 20done.	 CV RMSE: 1.1110555089993142
#
#  Model 21done.	 CV RMSE: 1.3676626645087957
#
#  Model 22done.	 CV RMSE: 1.3001990920349498
#
#  Model 23done.	 CV RMSE: 1.1606449714061944
#
#  Model 24done.	 CV RMSE: 1.111007230686095
#
#  Model 25done.	 CV RMSE: 1.36653279952983
#
#  Model 26done.	 CV RMSE: 1.2831790299496835
#
#  Model 27done.	 CV RMSE: 1.1594207524783124
#
#  Model 28done.	 CV RMSE: 1.1112406114394386
#
#  Model 29done.	 CV RMSE: 1.3663202944222992
#
#  Model 30done.	 CV RMSE: 1.2831806871137852
#
#  Model 31done.	 CV RMSE: 1.1594471891159535
#
#  Model 32done.	 CV RMSE: 1.1110557609748053
#
#  Model 33done.	 CV RMSE: 1.366112327126087
#
#  Model 34done.	 CV RMSE: 1.2829980946139423
#
#  Model 35done.	 CV RMSE: 1.1593630997788444
#
#  Model 36done.	 CV RMSE: 1.1110075322011785
# CV size 0.8371431228494374
# model_Items_5
#
#  Model 1done.	 CV RMSE: 2.552560122606434
#
#  Model 2done.	 CV RMSE: 2.0416544082210737
#
#  Model 3done.	 CV RMSE: 1.6667552426249934
#
#  Model 4done.	 CV RMSE: 1.1249905382449796
#
#  Model 5done.	 CV RMSE: 1.6529510225179223
#
#  Model 6done.	 CV RMSE: 1.4815400817466196
#
#  Model 7done.	 CV RMSE: 1.2549271774719073
#
#  Model 8done.	 CV RMSE: 1.0877519275503518
#
#  Model 9done.	 CV RMSE: 1.543245459814658
#
#  Model 10done.	 CV RMSE: 1.4012456613996345
#
#  Model 11done.	 CV RMSE: 1.179452568338738
#
#  Model 12done.	 CV RMSE: 1.0698655986374206
#
#  Model 13done.	 CV RMSE: 2.646426278699309
#
#  Model 14done.	 CV RMSE: 2.1413122947594463
#
#  Model 15done.	 CV RMSE: 1.6583876596343679
#
#  Model 16done.	 CV RMSE: 1.1250161715528921
#
#  Model 17done.	 CV RMSE: 1.622006698570466
#
#  Model 18done.	 CV RMSE: 1.4724925284497457
#
#  Model 19done.	 CV RMSE: 1.232277983631055
#
#  Model 20done.	 CV RMSE: 1.088207231487052
#
#  Model 21done.	 CV RMSE: 1.5173753472452134
#
#  Model 22done.	 CV RMSE: 1.389479889303126
#
#  Model 23done.	 CV RMSE: 1.160184896426278
#
#  Model 24done.	 CV RMSE: 1.0696580722539832
#
#  Model 25done.	 CV RMSE: 2.7115182618060767
#
#  Model 26done.	 CV RMSE: 2.2162256891083048
#
#  Model 27done.	 CV RMSE: 1.6509658315055467
#
#  Model 28done.	 CV RMSE: 1.1260528165311119
#
#  Model 29done.	 CV RMSE: 1.6019019504631158
#
#  Model 30done.	 CV RMSE: 1.4659682155198994
#
#  Model 31done.	 CV RMSE: 1.2196487581191173
#
#  Model 32done.	 CV RMSE: 1.0884317787994382
#
#  Model 33done.	 CV RMSE: 1.5006283128133049
#
#  Model 34done.	 CV RMSE: 1.3797926615984955
#
#  Model 35done.	 CV RMSE: 1.1509760270223657
#
#  Model 36done.	 CV RMSE: 1.0696045294806524
# CV size 0.5335316884086747
# model_Items_25
#
#  Model 1done.	 CV RMSE: 2.141162019377674
#
#  Model 2done.	 CV RMSE: 1.7530833879508825
#
#  Model 3done.	 CV RMSE: 1.5703402013847814
#
#  Model 4done.	 CV RMSE: 1.106022922440157
#
#  Model 5done.	 CV RMSE: 2.1519735208013797
#
#  Model 6done.	 CV RMSE: 1.8816534534568907
#
#  Model 7done.	 CV RMSE: 1.7533050270650636
#
#  Model 8done.	 CV RMSE: 1.1915942665239287
#
#  Model 9done.	 CV RMSE: 2.1695977680918546
#
#  Model 10done.	 CV RMSE: 1.9840174004240407
#
#  Model 11done.	 CV RMSE: 1.86070444758823
#
#  Model 12done.	 CV RMSE: 1.2323766717882445
#
#  Model 13done.	 CV RMSE: 2.3601567449113716
#
#  Model 14done.	 CV RMSE: 1.9175745644646993
#
#  Model 15done.	 CV RMSE: 1.638181929855541
#
#  Model 16done.	 CV RMSE: 1.109359992792553
#
#  Model 17done.	 CV RMSE: 2.3224569283318433
#
#  Model 18done.	 CV RMSE: 2.032541292841495
#
#  Model 19done.	 CV RMSE: 1.8511416157486664
#
#  Model 20done.	 CV RMSE: 1.1952553205686929
#
#  Model 21done.	 CV RMSE: 2.3317410919078707
#
#  Model 22done.	 CV RMSE: 2.1392570593166482
#
#  Model 23done.	 CV RMSE: 1.9596820993392357
#
#  Model 24done.	 CV RMSE: 1.2352723271993444
#
#  Model 25done.	 CV RMSE: 2.5429936575618766
#
#  Model 26done.	 CV RMSE: 2.0731601503500023
#
#  Model 27done.	 CV RMSE: 1.6602977134456147
#
#  Model 28done.	 CV RMSE: 1.1098747441206795
#
#  Model 29done.	 CV RMSE: 2.449611071430511
#
#  Model 30done.	 CV RMSE: 2.1659108748464893
#
#  Model 31done.	 CV RMSE: 1.9091017883407133
#
#  Model 32done.	 CV RMSE: 1.197136603951163
#
#  Model 33done.	 CV RMSE: 2.4613016466684288
#
#  Model 34done.	 CV RMSE: 2.2610878673624737
#
#  Model 35done.	 CV RMSE: 2.0172741516894486
#
#  Model 36done.	 CV RMSE: 1.2388600076076226
# CV size 0.23629376466697116
# model_Items_125
#
#  Model 1done.	 CV RMSE: 1.1657346910449669
#
#  Model 2done.	 CV RMSE: 1.0472896531732814
#
#  Model 3done.	 CV RMSE: 0.9899740190111238
#
#  Model 4done.	 CV RMSE: 0.9279612471105296
#
#  Model 5done.	 CV RMSE: 1.251282660496548
#
#  Model 6done.	 CV RMSE: 1.1406926398629973
#
#  Model 7done.	 CV RMSE: 1.066341880723649
#
#  Model 8done.	 CV RMSE: 0.9639102260179853
#
#  Model 9done.	 CV RMSE: 1.3668118323912497
#
#  Model 10done.	 CV RMSE: 1.253598726216113
#
#  Model 11done.	 CV RMSE: 1.1656547389208247
#
#  Model 12done.	 CV RMSE: 1.0127367177648774
#
#  Model 13done.	 CV RMSE: 1.2051048806274307
#
#  Model 14done.	 CV RMSE: 1.0706105972232118
#
#  Model 15done.	 CV RMSE: 0.9995796068416367
#
#  Model 16done.	 CV RMSE: 0.9276300787081242
#
#  Model 17done.	 CV RMSE: 1.3061686676918085
#
#  Model 18done.	 CV RMSE: 1.169716591833615
#
#  Model 19done.	 CV RMSE: 1.0836040469710386
#
#  Model 20done.	 CV RMSE: 0.9625537157570947
#
#  Model 21done.	 CV RMSE: 1.4273312575986776
#
#  Model 22done.	 CV RMSE: 1.294990729688981
#
#  Model 23done.	 CV RMSE: 1.1928240912617378
#
#  Model 24done.	 CV RMSE: 1.0120915405873954
#
#  Model 25done.	 CV RMSE: 1.2265382494897157
#
#  Model 26done.	 CV RMSE: 1.0808045856305193
#
#  Model 27done.	 CV RMSE: 1.0073109415263128
#
#  Model 28done.	 CV RMSE: 0.9250686299765203
#
#  Model 29done.	 CV RMSE: 1.34031252066494
#
#  Model 30done.	 CV RMSE: 1.198337485757328
#
#  Model 31done.	 CV RMSE: 1.0928769460472327
#
#  Model 32done.	 CV RMSE: 0.9621987271665591
#
#  Model 33done.	 CV RMSE: 1.476180698548064
#
#  Model 34done.	 CV RMSE: 1.3309889140892797
#
#  Model 35done.	 CV RMSE: 1.2100873570175459
#
#  Model 36done.	 CV RMSE: 1.012341282860102
# CV size 0.1167174718345744
# model_Items_625
#
#  Model 1done.	 CV RMSE: 0.8956941519919311
#
#  Model 2done.	 CV RMSE: 0.8905198840704304
#
#  Model 3done.	 CV RMSE: 0.8807581148116528
#
#  Model 4done.	 CV RMSE: 0.8757688452567569
#
#  Model 5done.	 CV RMSE: 0.9112689520120865
#
#  Model 6done.	 CV RMSE: 0.9035297362646719
#
#  Model 7done.	 CV RMSE: 0.8892049673460586
#
#  Model 8done.	 CV RMSE: 0.8706663234055259
#
#  Model 9done.	 CV RMSE: 0.9622759762889223
#
#  Model 10done.	 CV RMSE: 0.9404663242444041
#
#  Model 11done.	 CV RMSE: 0.912765448293447
#
#  Model 12done.	 CV RMSE: 0.8751048847827898
#
#  Model 13done.	 CV RMSE: 0.9024189008521651
#
#  Model 14done.	 CV RMSE: 0.8916994866334068
#
#  Model 15done.	 CV RMSE: 0.8809632027893581
#
#  Model 16done.	 CV RMSE: 0.8757659529593742
#
#  Model 17done.	 CV RMSE: 0.9154887292866042
#
#  Model 18done.	 CV RMSE: 0.9058932656048391
#
#  Model 19done.	 CV RMSE: 0.8895244711950581
#
#  Model 20done.	 CV RMSE: 0.8708406466025328
#
#  Model 21done.	 CV RMSE: 0.9802723992021153
#
#  Model 22done.	 CV RMSE: 0.9477368140973127
#
#  Model 23done.	 CV RMSE: 0.9145218812754988
#
#  Model 24done.	 CV RMSE: 0.8751876326002682
#
#  Model 25done.	 CV RMSE: 0.9102769681313392
#
#  Model 26done.	 CV RMSE: 0.8896623213023561
#
#  Model 27done.	 CV RMSE: 0.8808701996069561
#
#  Model 28done.	 CV RMSE: 0.8757583291996823
#
#  Model 29done.	 CV RMSE: 0.9200747894056658
#
#  Model 30done.	 CV RMSE: 0.9081770422208107
#
#  Model 31done.	 CV RMSE: 0.8900493301573744
#
#  Model 32done.	 CV RMSE: 0.8709386745558936
#
#  Model 33done.	 CV RMSE: 0.9869814656990713
#
#  Model 34done.	 CV RMSE: 0.9496638549164006
#
#  Model 35done.	 CV RMSE: 0.9153106318961736
#
#  Model 36done.	 CV RMSE: 0.8753027914502793
# CV size 0.09999911129675135
# model_Items_inf
#
#  Model 1done.	 CV RMSE: 0.8894064922661781
#
#  Model 2done.	 CV RMSE: 0.8811486205492839
#
#  Model 3done.	 CV RMSE: 0.8761648500417049
#
#  Model 4done.	 CV RMSE: 0.8721195881985351
#
#  Model 5done.	 CV RMSE: 0.8825192597053337
#
#  Model 6done.	 CV RMSE: 0.8812291476653358
#
#  Model 7done.	 CV RMSE: 0.8747651431189952
#
#  Model 8done.	 CV RMSE: 0.8626779771362061
#
#  Model 9done.	 CV RMSE: 0.9028473298863007
#
#  Model 10done.	 CV RMSE: 0.9008236623206356
#
#  Model 11done.	 CV RMSE: 0.8894449166289823
#
#  Model 12done.	 CV RMSE: 0.8629279197371013
#
#  Model 13done.	 CV RMSE: 0.8961339256466629
#
#  Model 14done.	 CV RMSE: 0.8805283172206883
#
#  Model 15done.	 CV RMSE: 0.8762263895955366
#
#  Model 16done.	 CV RMSE: 0.8720965951591964
#
#  Model 17done.	 CV RMSE: 0.886739682883953
#
#  Model 18done.	 CV RMSE: 0.8833398851111052
#
#  Model 19done.	 CV RMSE: 0.8754480229463377
#
#  Model 20done.	 CV RMSE: 0.8627044967116283
#
#  Model 21done.	 CV RMSE: 0.9089605518296667
#
#  Model 22done.	 CV RMSE: 0.9059567146848342
#
#  Model 23done.	 CV RMSE: 0.8897233359286226
#
#  Model 24done.	 CV RMSE: 0.8628881962697693
#
#  Model 25done.	 CV RMSE: 0.8983846534900136
#
#  Model 26done.	 CV RMSE: 0.8780587665540871
#
#  Model 27done.	 CV RMSE: 0.8761818801188016
#
#  Model 28done.	 CV RMSE: 0.8720833029959351
#
#  Model 29done.	 CV RMSE: 0.8890684043920588
#
#  Model 30done.	 CV RMSE: 0.8842660497539386
#
#  Model 31done.	 CV RMSE: 0.8757042062817404
#
#  Model 32done.	 CV RMSE: 0.862716997562186
#
#  Model 33done.	 CV RMSE: 0.9129205251195687
#
#  Model 34done.	 CV RMSE: 0.9092140073610228
#
#  Model 35done.	 CV RMSE: 0.8894947266437371
#
#  Model 36done.	 CV RMSE: 0.862866193831085

# %%
pickle.dump(basic_model_sub_items,open("./dump_basic_model_sub_items","wb"))

# %%
#check best RMSE
m = {}
mi = 10.0

for key in basic_model_sub_items.keys():
    for k2 in basic_model_sub_items[key].keys():
        if basic_model_sub_items[key][k2]["cv_rmse"] <= mi:
            mi = basic_model_sub_items[key][k2]["cv_rmse"]
            m[basic_model_sub_items[key][k2]["cv_rmse"]] = key+"_"+k2
        
        
print("Best model: ",m[mi],"\t","best cv error",mi)
# Out:
# Best model:  model_Items_inf_model_seq_ 8_50_4_1.0 	 best cv error 0.8626779771362061

# %% [markdown]
# ##### Users

# %%
basic_model_sub_users = subsample_user_item('./ml-1m/ratings.dat','Users')
# Out:
# CV size 0.9371213225343022
# model_Users_1
#
#  Model 1done.	 CV RMSE: 1.4757187828208054
#
#  Model 2done.	 CV RMSE: 1.406855552533479
#
#  Model 3done.	 CV RMSE: 1.1756997073724276
#
#  Model 4done.	 CV RMSE: 1.0935054747553064
#
#  Model 5done.	 CV RMSE: 1.4758751133768713
#
#  Model 6done.	 CV RMSE: 1.4064121261726847
#
#  Model 7done.	 CV RMSE: 1.1755697600960564
#
#  Model 8done.	 CV RMSE: 1.0914237640358124
#
#  Model 9done.	 CV RMSE: 1.4756229345318919
#
#  Model 10done.	 CV RMSE: 1.4054699031320517
#
#  Model 11done.	 CV RMSE: 1.1754443582228566
#
#  Model 12done.	 CV RMSE: 1.0905740345797992
#
#  Model 13done.	 CV RMSE: 1.4736380832663967
#
#  Model 14done.	 CV RMSE: 1.3768998987638943
#
#  Model 15done.	 CV RMSE: 1.175203810594718
#
#  Model 16done.	 CV RMSE: 1.0935008434426992
#
#  Model 17done.	 CV RMSE: 1.4737134264992648
#
#  Model 18done.	 CV RMSE: 1.3767478525788563
#
#  Model 19done.	 CV RMSE: 1.1749597861786043
#
#  Model 20done.	 CV RMSE: 1.0914226867043093
#
#  Model 21done.	 CV RMSE: 1.47345612520456
#
#  Model 22done.	 CV RMSE: 1.3762651375903427
#
#  Model 23done.	 CV RMSE: 1.1747973468557646
#
#  Model 24done.	 CV RMSE: 1.0905741168233303
#
#  Model 25done.	 CV RMSE: 1.4716377332463464
#
#  Model 26done.	 CV RMSE: 1.3505026190738072
#
#  Model 27done.	 CV RMSE: 1.1741753219196311
#
#  Model 28done.	 CV RMSE: 1.0934990178878647
#
#  Model 29done.	 CV RMSE: 1.4715651552116593
#
#  Model 30done.	 CV RMSE: 1.3504650308201427
#
#  Model 31done.	 CV RMSE: 1.1740074938677354
#
#  Model 32done.	 CV RMSE: 1.0914224489897157
#
#  Model 33done.	 CV RMSE: 1.4712959868647293
#
#  Model 34done.	 CV RMSE: 1.3502769051622971
#
#  Model 35done.	 CV RMSE: 1.1739090326595936
#
#  Model 36done.	 CV RMSE: 1.0905743099003915
# CV size 0.8816823052361457
# model_Users_2
#
#  Model 1done.	 CV RMSE: 1.5109619302342143
#
#  Model 2done.	 CV RMSE: 1.4156748154522876
#
#  Model 3done.	 CV RMSE: 1.2333588830064182
#
#  Model 4done.	 CV RMSE: 1.0940420996869475
#
#  Model 5done.	 CV RMSE: 1.4331889928859234
#
#  Model 6done.	 CV RMSE: 1.34214429722963
#
#  Model 7done.	 CV RMSE: 1.1585483096437281
#
#  Model 8done.	 CV RMSE: 1.070688506739777
#
#  Model 9done.	 CV RMSE: 1.4296980130118475
#
#  Model 10done.	 CV RMSE: 1.3358461624345697
#
#  Model 11done.	 CV RMSE: 1.147373807661326
#
#  Model 12done.	 CV RMSE: 1.063277049037222
#
#  Model 13done.	 CV RMSE: 1.4927582611792738
#
#  Model 14done.	 CV RMSE: 1.4064736424677533
#
#  Model 15done.	 CV RMSE: 1.2279844311213524
#
#  Model 16done.	 CV RMSE: 1.0939168687545477
#
#  Model 17done.	 CV RMSE: 1.415298148111235
#
#  Model 18done.	 CV RMSE: 1.3274530189306948
#
#  Model 19done.	 CV RMSE: 1.1500701348245186
#
#  Model 20done.	 CV RMSE: 1.070411514526275
#
#  Model 21done.	 CV RMSE: 1.4118261727217865
#
#  Model 22done.	 CV RMSE: 1.3200648030220803
#
#  Model 23done.	 CV RMSE: 1.137634537486723
#
#  Model 24done.	 CV RMSE: 1.0632125246845867
#
#  Model 25done.	 CV RMSE: 1.4827662049480015
#
#  Model 26done.	 CV RMSE: 1.3969626374825053
#
#  Model 27done.	 CV RMSE: 1.2251305314277938
#
#  Model 28done.	 CV RMSE: 1.0939867496400473
#
#  Model 29done.	 CV RMSE: 1.4047995269543625
#
#  Model 30done.	 CV RMSE: 1.3139308958962863
#
#  Model 31done.	 CV RMSE: 1.1447567315776443
#
#  Model 32done.	 CV RMSE: 1.070566142782457
#
#  Model 33done.	 CV RMSE: 1.401273789548566
#
#  Model 34done.	 CV RMSE: 1.305706851537494
#
#  Model 35done.	 CV RMSE: 1.1312653045173378
#
#  Model 36done.	 CV RMSE: 1.0631446128954603
# CV size 0.7884005675349016
# model_Users_4
#
#  Model 1done.	 CV RMSE: 2.8793658470063415
#
#  Model 2done.	 CV RMSE: 2.208099840419274
#
#  Model 3done.	 CV RMSE: 1.8288657833485504
#
#  Model 4done.	 CV RMSE: 1.1740967993459819
#
#  Model 5done.	 CV RMSE: 1.625029496243311
#
#  Model 6done.	 CV RMSE: 1.4891041505044416
#
#  Model 7done.	 CV RMSE: 1.3340887554089262
#
#  Model 8done.	 CV RMSE: 1.1158436341221374
#
#  Model 9done.	 CV RMSE: 1.4891716648002555
#
#  Model 10done.	 CV RMSE: 1.3840706432341447
#
#  Model 11done.	 CV RMSE: 1.2226134622247922
#
#  Model 12done.	 CV RMSE: 1.0809671365057458
#
#  Model 13done.	 CV RMSE: 3.1309327980403308
#
#  Model 14done.	 CV RMSE: 2.3618455825956213
#
#  Model 15done.	 CV RMSE: 1.8657638964599026
#
#  Model 16done.	 CV RMSE: 1.1741976390795508
#
#  Model 17done.	 CV RMSE: 1.5974078959517348
#
#  Model 18done.	 CV RMSE: 1.4887234852765712
#
#  Model 19done.	 CV RMSE: 1.3174692175890348
#
#  Model 20done.	 CV RMSE: 1.1152463830438788
#
#  Model 21done.	 CV RMSE: 1.4673162452122448
#
#  Model 22done.	 CV RMSE: 1.3793883808331222
#
#  Model 23done.	 CV RMSE: 1.2063235455907484
#
#  Model 24done.	 CV RMSE: 1.0807567140799594
#
#  Model 25done.	 CV RMSE: 3.355556204955402
#
#  Model 26done.	 CV RMSE: 2.4921959928607986
#
#  Model 27done.	 CV RMSE: 1.8809989374847749
#
#  Model 28done.	 CV RMSE: 1.1738236186760582
#
#  Model 29done.	 CV RMSE: 1.5792899614148488
#
#  Model 30done.	 CV RMSE: 1.4878747125002754
#
#  Model 31done.	 CV RMSE: 1.307462815179722
#
#  Model 32done.	 CV RMSE: 1.115340034740935
#
#  Model 33done.	 CV RMSE: 1.45273788535264
#
#  Model 34done.	 CV RMSE: 1.375135316213113
#
#  Model 35done.	 CV RMSE: 1.1967735862068423
#
#  Model 36done.	 CV RMSE: 1.081089230125413
# CV size 0.4825382871171958
# model_Users_16
#
#  Model 1done.	 CV RMSE: 2.3431022047616348
#
#  Model 2done.	 CV RMSE: 1.8670993850216566
#
#  Model 3done.	 CV RMSE: 1.446539831206085
#
#  Model 4done.	 CV RMSE: 1.0890335324818174
#
#  Model 5done.	 CV RMSE: 2.244101231721717
#
#  Model 6done.	 CV RMSE: 2.002815163772272
#
#  Model 7done.	 CV RMSE: 1.7244629326925283
#
#  Model 8done.	 CV RMSE: 1.1995467987606334
#
#  Model 9done.	 CV RMSE: 2.213996434636114
#
#  Model 10done.	 CV RMSE: 2.0861880574254723
#
#  Model 11done.	 CV RMSE: 1.8726606002801502
#
#  Model 12done.	 CV RMSE: 1.271859583957963
#
#  Model 13done.	 CV RMSE: 2.7527138394280457
#
#  Model 14done.	 CV RMSE: 2.1134535621152786
#
#  Model 15done.	 CV RMSE: 1.4657104458761878
#
#  Model 16done.	 CV RMSE: 1.087897856432727
#
#  Model 17done.	 CV RMSE: 2.567030414198449
#
#  Model 18done.	 CV RMSE: 2.1664574423977045
#
#  Model 19done.	 CV RMSE: 1.7992357619450419
#
#  Model 20done.	 CV RMSE: 1.2015440093876646
#
#  Model 21done.	 CV RMSE: 2.4445488139913643
#
#  Model 22done.	 CV RMSE: 2.2704193757463105
#
#  Model 23done.	 CV RMSE: 1.9691276749620066
#
#  Model 24done.	 CV RMSE: 1.2793653647019565
#
#  Model 25done.	 CV RMSE: 3.1458947398639885
#
#  Model 26done.	 CV RMSE: 2.3414784073491393
#
#  Model 27done.	 CV RMSE: 1.4750372018510114
#
#  Model 28done.	 CV RMSE: 1.0875739797894652
#
#  Model 29done.	 CV RMSE: 2.848151260000562
#
#  Model 30done.	 CV RMSE: 2.2977911066365295
#
#  Model 31done.	 CV RMSE: 1.8457276268990057
#
#  Model 32done.	 CV RMSE: 1.2047655210433077
#
#  Model 33done.	 CV RMSE: 2.624812670541974
#
#  Model 34done.	 CV RMSE: 2.4111932649761956
#
#  Model 35done.	 CV RMSE: 2.0302116711992992
#
#  Model 36done.	 CV RMSE: 1.2817826542614215
# CV size 0.3315274836571218
# model_Users_32
#
#  Model 1done.	 CV RMSE: 1.5841098636127944
#
#  Model 2done.	 CV RMSE: 1.3974827004585946
#
#  Model 3done.	 CV RMSE: 1.1298030627487294
#
#  Model 4done.	 CV RMSE: 0.9737159483253964
#
#  Model 5done.	 CV RMSE: 1.5084163058959936
#
#  Model 6done.	 CV RMSE: 1.4562037367743819
#
#  Model 7done.	 CV RMSE: 1.3082396415797253
#
#  Model 8done.	 CV RMSE: 1.0550853818904222
#
#  Model 9done.	 CV RMSE: 1.587124523359288
#
#  Model 10done.	 CV RMSE: 1.5709154006872363
#
#  Model 11done.	 CV RMSE: 1.4654555530150977
#
#  Model 12done.	 CV RMSE: 1.1321913988500698
#
#  Model 13done.	 CV RMSE: 1.818030462250011
#
#  Model 14done.	 CV RMSE: 1.506968442803744
#
#  Model 15done.	 CV RMSE: 1.134072550406161
#
#  Model 16done.	 CV RMSE: 0.9702358441852401
#
#  Model 17done.	 CV RMSE: 1.6401007201422757
#
#  Model 18done.	 CV RMSE: 1.5633702651050667
#
#  Model 19done.	 CV RMSE: 1.3426158229299892
#
#  Model 20done.	 CV RMSE: 1.0555136482226612
#
#  Model 21done.	 CV RMSE: 1.6987840077879135
#
#  Model 22done.	 CV RMSE: 1.6751806026158733
#
#  Model 23done.	 CV RMSE: 1.5128644718900115
#
#  Model 24done.	 CV RMSE: 1.1355033339576008
#
#  Model 25done.	 CV RMSE: 2.000926809994239
#
#  Model 26done.	 CV RMSE: 1.6214640453507203
#
#  Model 27done.	 CV RMSE: 1.1344092604180238
#
#  Model 28done.	 CV RMSE: 0.9680805910292134
#
#  Model 29done.	 CV RMSE: 1.7797154262360868
#
#  Model 30done.	 CV RMSE: 1.6424553052272937
#
#  Model 31done.	 CV RMSE: 1.3565572503077132
#
#  Model 32done.	 CV RMSE: 1.0537316355888222
#
#  Model 33done.	 CV RMSE: 1.7856898246275
#
#  Model 34done.	 CV RMSE: 1.7605522868471297
#
#  Model 35done.	 CV RMSE: 1.545271495578065
#
#  Model 36done.	 CV RMSE: 1.135146442464158
# CV size 0.09999911129675135
# model_Users_inf
#
#  Model 1done.	 CV RMSE: 0.8809537257541866
#
#  Model 2done.	 CV RMSE: 0.8802820783007432
#
#  Model 3done.	 CV RMSE: 0.8758564835677176
#
#  Model 4done.	 CV RMSE: 0.8715321985669836
#
#  Model 5done.	 CV RMSE: 0.8902861071767592
#
#  Model 6done.	 CV RMSE: 0.8880975483820251
#
#  Model 7done.	 CV RMSE: 0.8784470578110511
#
#  Model 8done.	 CV RMSE: 0.865361672135349
#
#  Model 9done.	 CV RMSE: 0.9101816832408643
#
#  Model 10done.	 CV RMSE: 0.9061032402332597
#
#  Model 11done.	 CV RMSE: 0.8915932891521112
#
#  Model 12done.	 CV RMSE: 0.8640353470493134
#
#  Model 13done.	 CV RMSE: 0.882817298689741
#
#  Model 14done.	 CV RMSE: 0.8812900419263673
#
#  Model 15done.	 CV RMSE: 0.8756543511142498
#
#  Model 16done.	 CV RMSE: 0.8715252432324337
#
#  Model 17done.	 CV RMSE: 0.8923836998200364
#
#  Model 18done.	 CV RMSE: 0.8899498328808857
#
#  Model 19done.	 CV RMSE: 0.8786310680840406
#
#  Model 20done.	 CV RMSE: 0.8649227004596103
#
#  Model 21done.	 CV RMSE: 0.9129080834821295
#
#  Model 22done.	 CV RMSE: 0.908008049705739
#
#  Model 23done.	 CV RMSE: 0.8946829347034749
#
#  Model 24done.	 CV RMSE: 0.8637529587686669
#
#  Model 25done.	 CV RMSE: 0.8845908781985542
#
#  Model 26done.	 CV RMSE: 0.8820419112816575
#
#  Model 27done.	 CV RMSE: 0.8755935407893428
#
#  Model 28done.	 CV RMSE: 0.8715168823653326
#
#  Model 29done.	 CV RMSE: 0.8946101714327217
#
#  Model 30done.	 CV RMSE: 0.8912657274590066
#
#  Model 31done.	 CV RMSE: 0.8786830869321437
#
#  Model 32done.	 CV RMSE: 0.8646625429760527
#
#  Model 33done.	 CV RMSE: 0.9132026005754028
#
#  Model 34done.	 CV RMSE: 0.9140554839887288
#
#  Model 35done.	 CV RMSE: 0.8957064594289156
#
#  Model 36done.	 CV RMSE: 0.8637394805622824

# %%
pickle.dump(basic_model_sub_users,open("./dump_basic_model_sub_users","wb"))

# %%
#check best RMSE
m = {}
mi = 10.0

for key in basic_model_sub_users.keys():
    for k2 in basic_model_sub_users[key].keys():
        if basic_model_sub_users[key][k2]["cv_rmse"] <= mi:
            mi = basic_model_sub_users[key][k2]["cv_rmse"]
            m[basic_model_sub_users[key][k2]["cv_rmse"]] = key+"_"+k2
        
        
print("Best model: ",m[mi],"\t","best cv error",mi)
# Out:
# Best model:  model_Users_inf_model_seq_ 36_100_6_1.0 	 best cv error 0.8637394805622824

# %% [markdown]
# ### Regressor 2: Side information

# %%
def load_data_side_info(ratings_file_,user_file_,movie_file_):
    
    '''
    Input 
    
        File_ : file name of the ratings file
    
    Output : test - train dfs
    '''

    users = pd.read_csv(user_file_, sep='::', names=['userId', 'gender', 'age', 'occupation', 'zip'], \
                    header=None)

    movies = pd.read_csv(movie_file_, sep='::', names=['movieId', 'title', 'genres'], header=None)
    movies.head()
    movies['year'] = movies.title.apply(lambda x : x[-5:-1])
    
    sparse_genres = pd.DataFrame(CountVectorizer().fit_transform(movies.genres\
                                    .map(lambda x: x.replace('|', ' '))).todense())
    
    movies = pd.concat([movies[['movieId']], sparse_genres], axis=1) 
    
    
    ratings = np.genfromtxt(ratings_file_,delimiter="::")
    ratings =  pd.DataFrame(ratings)
    
    ratings.columns = ['userId','movieId','rating','timestamp']
    ratings = ratings.drop('timestamp', axis=1)
    
    ratings = pd.merge(pd.merge(ratings, users, on='userId'), movies, on='movieId')
    
    y = ratings['rating'].values
    X = ratings.drop('rating', axis=1)
    for feature in X.columns:
        _,X[feature] = np.unique(X[feature], return_inverse=True)
    
    encoder = encode(X)
    trainX, testX, trainY, testY = train_test_split(X, y, test_size=0.20, random_state=1234)
    
    
    ##fixed
    #trainX, testX, trainY, testY = train_test_split(X, y, test_size=0.10, random_state=1234)
    trainX = encoder.transform(trainX)
    testX = encoder.transform(testX)
    
    return (X.userId.nunique(),X.movieId.nunique()),trainX, testX, trainY, testY

# %% [markdown]
# #### Add feature 1 : performe the test1 and test2

# %% [markdown]
# #### Running it for 150 iterations

# %%
###store function return
#trainX, testX, trainY, testY = load_data_simple('./ml-1m/ratings.dat')
files = (('./ml-1m/ratings.dat'),('./ml-1m/users.dat'),('./ml-1m/movies.dat'))
add_info_model = subsample_user_item(files,model_type = "side_info")
#pickle object for later use
# Out:
# /home/som/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   # This is added back by InteractiveShellApp.init_path()
# /home/som/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   del sys.path[0]
# model_All_0.2
#
#  Model 1done.	 CV RMSE: 1.8361533643150856
#
#  Model 2done.	 CV RMSE: 1.4190197950185062
#
#  Model 3done.	 CV RMSE: 1.1317654798743346
#
#  Model 4done.	 CV RMSE: 0.9849017276244169
#
#  Model 5done.	 CV RMSE: 2.4580026018095493
#
#  Model 6done.	 CV RMSE: 1.5830739508574916
#
#  Model 7done.	 CV RMSE: 1.268978146697139
#
#  Model 8done.	 CV RMSE: 1.044802179011477
#
#  Model 9done.	 CV RMSE: 1.8815711273305318
#
#  Model 10done.	 CV RMSE: 1.7017528980470988
#
#  Model 11done.	 CV RMSE: 1.4064450187758057
#
#  Model 12done.	 CV RMSE: 1.0971355755595265
#
#  Model 13done.	 CV RMSE: 2.146025364368289
#
#  Model 14done.	 CV RMSE: 1.510842409168484
#
#  Model 15done.	 CV RMSE: 1.1491794866409097
#
#  Model 16done.	 CV RMSE: 0.985844958843531
#
#  Model 17done.	 CV RMSE: 2.5961793613528292
#
#  Model 18done.	 CV RMSE: 1.6571141460662981
#
#  Model 19done.	 CV RMSE: 1.316940493779122
#
#  Model 20done.	 CV RMSE: 1.0467791973244598
#
#  Model 21done.	 CV RMSE: 2.0848317692516636
#
#  Model 22done.	 CV RMSE: 1.8549660131527201
#
#  Model 23done.	 CV RMSE: 1.4576804800821284
#
#  Model 24done.	 CV RMSE: 1.1018975799432789
#
#  Model 25done.	 CV RMSE: 2.301261749510562
#
#  Model 26done.	 CV RMSE: 1.5965069681195463
#
#  Model 27done.	 CV RMSE: 1.157835637947434
#
#  Model 28done.	 CV RMSE: 0.9866309060346227
#
#  Model 29done.	 CV RMSE: 2.674308317017873
#
#  Model 30done.	 CV RMSE: 1.756007710681765
#
#  Model 31done.	 CV RMSE: 1.3501346712641205
#
#  Model 32done.	 CV RMSE: 1.0495389022402624
#
#  Model 33done.	 CV RMSE: 2.2866325731220534
#
#  Model 34done.	 CV RMSE: 1.9698112301136397
#
#  Model 35done.	 CV RMSE: 1.4903487033896388
#
#  Model 36done.	 CV RMSE: 1.1043900907298987
#
#  Model 37done.	 CV RMSE: 2.455949317191699
#
#  Model 38done.	 CV RMSE: 1.6843907526959618
#
#  Model 39done.	 CV RMSE: 1.161984838184896
#
#  Model 40done.	 CV RMSE: 0.9872325566132029
#
#  Model 41done.	 CV RMSE: 2.725209746043195
#
#  Model 42done.	 CV RMSE: 1.8359434244356352
#
#  Model 43done.	 CV RMSE: 1.3707313347057573
#
#  Model 44done.	 CV RMSE: 1.0523241452348153
#
#  Model 45done.	 CV RMSE: 2.4844345555733898
#
#  Model 46done.	 CV RMSE: 2.0615458271534424
#
#  Model 47done.	 CV RMSE: 1.5131358373764796
#
#  Model 48done.	 CV RMSE: 1.106773901467065
#
#  Model 49done.	 CV RMSE: 2.6670360968882405
#
#  Model 50done.	 CV RMSE: 1.754064701397659
#
#  Model 51done.	 CV RMSE: 1.1635993219189595
#
#  Model 52done.	 CV RMSE: 0.9870279097921845
#
#  Model 53done.	 CV RMSE: 2.743547563973707
#
#  Model 54done.	 CV RMSE: 1.906445336013194
#
#  Model 55done.	 CV RMSE: 1.3846786838052638
#
#  Model 56done.	 CV RMSE: 1.0539091744926887
#
#  Model 57done.	 CV RMSE: 2.6809010186023334
#
#  Model 58done.	 CV RMSE: 2.133657762735251
#
#  Model 59done.	 CV RMSE: 1.528829956091083
#
#  Model 60done.	 CV RMSE: 1.1090653716924257
# model_All_0.4
#
#  Model 1done.	 CV RMSE: 1.1339434999078342
#
#  Model 2done.	 CV RMSE: 1.0340371556995345
#
#  Model 3done.	 CV RMSE: 0.9727155651491993
#
#  Model 4done.	 CV RMSE: 0.9223419425941779
#
#  Model 5done.	 CV RMSE: 1.1855253175459082
#
#  Model 6done.	 CV RMSE: 1.1362909720287138
#
#  Model 7done.	 CV RMSE: 1.0451366385287075
#
#  Model 8done.	 CV RMSE: 0.9450951697566825
#
#  Model 9done.	 CV RMSE: 1.356198338326863
#
#  Model 10done.	 CV RMSE: 1.2946498980284737
#
#  Model 11done.	 CV RMSE: 1.1411317953702746
#
#  Model 12done.	 CV RMSE: 0.9775339962840902
#
#  Model 13done.	 CV RMSE: 1.1644841303900073
#
#  Model 14done.	 CV RMSE: 1.0636155774713598
#
#  Model 15done.	 CV RMSE: 0.9810602514828051
#
#  Model 16done.	 CV RMSE: 0.9218567452965768
#
#  Model 17done.	 CV RMSE: 1.2501819335215223
#
#  Model 18done.	 CV RMSE: 1.1865778956110262
#
#  Model 19done.	 CV RMSE: 1.058615268369221
#
#  Model 20done.	 CV RMSE: 0.9427934763272703
#
#  Model 21done.	 CV RMSE: 1.4442043413718126
#
#  Model 22done.	 CV RMSE: 1.3602742934906948
#
#  Model 23done.	 CV RMSE: 1.164534459681273
#
#  Model 24done.	 CV RMSE: 0.9776006100958667
#
#  Model 25done.	 CV RMSE: 1.1879181353611776
#
#  Model 26done.	 CV RMSE: 1.0883059389551524
#
#  Model 27done.	 CV RMSE: 0.9860224455871133
#
#  Model 28done.	 CV RMSE: 0.9211254626577257
#
#  Model 29done.	 CV RMSE: 1.3085465086941315
#
#  Model 30done.	 CV RMSE: 1.2215615196325627
#
#  Model 31done.	 CV RMSE: 1.0654453935772477
#
#  Model 32done.	 CV RMSE: 0.9419280296790783
#
#  Model 33done.	 CV RMSE: 1.514075121754869
#
#  Model 34done.	 CV RMSE: 1.4023008859538433
#
#  Model 35done.	 CV RMSE: 1.1806024010948688
#
#  Model 36done.	 CV RMSE: 0.9761541713237896
#
#  Model 37done.	 CV RMSE: 1.223721539714219
#
#  Model 38done.	 CV RMSE: 1.109353029409089
#
#  Model 39done.	 CV RMSE: 0.9882478086459833
#
#  Model 40done.	 CV RMSE: 0.9203278521553471
#
#  Model 41done.	 CV RMSE: 1.3592711501471804
#
#  Model 42done.	 CV RMSE: 1.247794966299267
#
#  Model 43done.	 CV RMSE: 1.0697233404524067
#
#  Model 44done.	 CV RMSE: 0.941687594998597
#
#  Model 45done.	 CV RMSE: 1.5715011636356462
#
#  Model 46done.	 CV RMSE: 1.4355089778726482
#
#  Model 47done.	 CV RMSE: 1.1932212241092808
#
#  Model 48done.	 CV RMSE: 0.9750606001114442
#
#  Model 49done.	 CV RMSE: 1.2477726941558962
#
#  Model 50done.	 CV RMSE: 1.127775632106524
#
#  Model 51done.	 CV RMSE: 0.9895132772759223
#
#  Model 52done.	 CV RMSE: 0.9192583302835531
#
#  Model 53done.	 CV RMSE: 1.4036953648706711
#
#  Model 54done.	 CV RMSE: 1.2710306979207286
#
#  Model 55done.	 CV RMSE: 1.0739999054702603
#
#  Model 56done.	 CV RMSE: 0.9420134592794422
#
#  Model 57done.	 CV RMSE: 1.6252548181092685
#
#  Model 58done.	 CV RMSE: 1.4655873277024896
#
#  Model 59done.	 CV RMSE: 1.200184026421757
#
#  Model 60done.	 CV RMSE: 0.9749314226734836
# model_All_0.6000000000000001
#
#  Model 1done.	 CV RMSE: 0.9421892270049859
#
#  Model 2done.	 CV RMSE: 0.937805415914473
#
#  Model 3done.	 CV RMSE: 0.9235800735619113
#
#  Model 4done.	 CV RMSE: 0.9008896420670717
#
#  Model 5done.	 CV RMSE: 0.9995649185066025
#
#  Model 6done.	 CV RMSE: 0.987350693844273
#
#  Model 7done.	 CV RMSE: 0.9486138869221064
#
#  Model 8done.	 CV RMSE: 0.9040520131359531
#
#  Model 9done.	 CV RMSE: 1.089864555076746
#
#  Model 10done.	 CV RMSE: 1.0682976450491564
#
#  Model 11done.	 CV RMSE: 1.0039212024948954
#
#  Model 12done.	 CV RMSE: 0.9192971896395822
#
#  Model 13done.	 CV RMSE: 0.9433375304036073
#
#  Model 14done.	 CV RMSE: 0.9367191388666547
#
#  Model 15done.	 CV RMSE: 0.9220792694055461
#
#  Model 16done.	 CV RMSE: 0.9009650429419379
#
#  Model 17done.	 CV RMSE: 1.0200747748507484
#
#  Model 18done.	 CV RMSE: 0.9999575966423643
#
#  Model 19done.	 CV RMSE: 0.9492749016663896
#
#  Model 20done.	 CV RMSE: 0.9034079244878555
#
#  Model 21done.	 CV RMSE: 1.123776182934125
#
#  Model 22done.	 CV RMSE: 1.0921941474238779
#
#  Model 23done.	 CV RMSE: 1.0120456066982497
#
#  Model 24done.	 CV RMSE: 0.9193829125779794
#
#  Model 25done.	 CV RMSE: 0.9501000510281733
#
#  Model 26done.	 CV RMSE: 0.9336701278265505
#
#  Model 27done.	 CV RMSE: 0.9193472363555466
#
#  Model 28done.	 CV RMSE: 0.9004437762253164
#
#  Model 29done.	 CV RMSE: 1.032156689664119
#
#  Model 30done.	 CV RMSE: 1.0087310476079547
#
#  Model 31done.	 CV RMSE: 0.9519657464105812
#
#  Model 32done.	 CV RMSE: 0.9035141713086968
#
#  Model 33done.	 CV RMSE: 1.1557764168885898
#
#  Model 34done.	 CV RMSE: 1.1113293830704314
#
#  Model 35done.	 CV RMSE: 1.0169768963452919
#
#  Model 36done.	 CV RMSE: 0.9200068418097026
#
#  Model 37done.	 CV RMSE: 0.9512754040597011
#
#  Model 38done.	 CV RMSE: 0.9318438236592735
#
#  Model 39done.	 CV RMSE: 0.9168177978862019
#
#  Model 40done.	 CV RMSE: 0.897976862584349
#
#  Model 41done.	 CV RMSE: 1.046899898307499
#
#  Model 42done.	 CV RMSE: 1.0192299738623
#
#  Model 43done.	 CV RMSE: 0.9556084803308138
#
#  Model 44done.	 CV RMSE: 0.903736102074082
#
#  Model 45done.	 CV RMSE: 1.18656967999176
#
#  Model 46done.	 CV RMSE: 1.1256644854126459
#
#  Model 47done.	 CV RMSE: 1.0221319012589258
#
#  Model 48done.	 CV RMSE: 0.9205138824117332
#
#  Model 49done.	 CV RMSE: 0.9543918473851071
#
#  Model 50done.	 CV RMSE: 0.9331025783532121
#
#  Model 51done.	 CV RMSE: 0.9160898988550933
#
#  Model 52done.	 CV RMSE: 0.8963738520189176
#
#  Model 53done.	 CV RMSE: 1.0643395766093777
#
#  Model 54done.	 CV RMSE: 1.0304819054353085
#
#  Model 55done.	 CV RMSE: 0.9589639665370885
#
#  Model 56done.	 CV RMSE: 0.9039514095484079
#
#  Model 57done.	 CV RMSE: 1.213058200592607
#
#  Model 58done.	 CV RMSE: 1.1373912146463934
#
#  Model 59done.	 CV RMSE: 1.0281261040371688
#
#  Model 60done.	 CV RMSE: 0.9209686118188483
# model_All_0.8
#
#  Model 1done.	 CV RMSE: 0.9108234651973073
#
#  Model 2done.	 CV RMSE: 0.9061008537306869
#
#  Model 3done.	 CV RMSE: 0.9004468706842854
#  Model 4done.	 CV RMSE: 0.8895153104777785
#
#  Model 5done.	 CV RMSE: 0.9412029283354142
#
#  Model 6done.	 CV RMSE: 0.9304536036355996
#
#  Model 7done.	 CV RMSE: 0.911453312333971
#
#  Model 8done.	 CV RMSE: 0.8864063772439899
#
#  Model 9done.	 CV RMSE: 1.0194074490434102
#
#  Model 10done.	 CV RMSE: 0.9928474595555475
#
#  Model 11done.	 CV RMSE: 0.9413568015289463
#
#  Model 12done.	 CV RMSE: 0.8929804139676623
#
#  Model 13done.	 CV RMSE: 0.913688194844385
#
#  Model 14done.	 CV RMSE: 0.9082610894736621
#
#  Model 15done.	 CV RMSE: 0.8997842834392341
#
#  Model 16done.	 CV RMSE: 0.8880172702663953
#
#  Model 17done.	 CV RMSE: 0.9503195969633562
#
#  Model 18done.	 CV RMSE: 0.9361064630940142
#
#  Model 19done.	 CV RMSE: 0.9122744484111537
#
#  Model 20done.	 CV RMSE: 0.8855476802905381
#
#  Model 21done.	 CV RMSE: 1.0423540036182752
#
#  Model 22done.	 CV RMSE: 1.0057491325320174
#
#  Model 23done.	 CV RMSE: 0.9447858482355536
#
#  Model 24done.	 CV RMSE: 0.8914790727211762
#
#  Model 25done.	 CV RMSE: 0.9155484558308289
#
#  Model 26done.	 CV RMSE: 0.9080784230282503
#
#  Model 27done.	 CV RMSE: 0.8981986359884525
#
#  Model 28done.	 CV RMSE: 0.8859921886853681
#
#  Model 29done.	 CV RMSE: 0.9583249559516451
#
#  Model 30done.	 CV RMSE: 0.9405540551163374
#
#  Model 31done.	 CV RMSE: 0.9132125488737793
#
#  Model 32done.	 CV RMSE: 0.8853023924858331
#
#  Model 33done.	 CV RMSE: 1.0616621919864757
#
#  Model 34done.	 CV RMSE: 1.0159341233034764
#
#  Model 35done.	 CV RMSE: 0.9472487459763308
#
#  Model 36done.	 CV RMSE: 0.8909371834112204
#
#  Model 37done.	 CV RMSE: 0.9173182277200038
#
#  Model 38done.	 CV RMSE: 0.9091573473799561
#
#  Model 39done.	 CV RMSE: 0.896392847509869
#
#  Model 40done.	 CV RMSE: 0.8852506312707908
#
#  Model 41done.	 CV RMSE: 0.9625527926185556
#
#  Model 42done.	 CV RMSE: 0.9429915987314965
#
#  Model 43done.	 CV RMSE: 0.9139629477328448
#
#  Model 44done.	 CV RMSE: 0.8850145207064608
#
#  Model 45done.	 CV RMSE: 1.0784445875709958
#
#  Model 46done.	 CV RMSE: 1.0210035077660256
#
#  Model 47done.	 CV RMSE: 0.9480248056295062
#
#  Model 48done.	 CV RMSE: 0.8907613885397166
#
#  Model 49done.	 CV RMSE: 0.9214586584159201
#
#  Model 50done.	 CV RMSE: 0.9107947439840585
#
#  Model 51done.	 CV RMSE: 0.8946904881068425
#
#  Model 52done.	 CV RMSE: 0.8850527727998292
#
#  Model 53done.	 CV RMSE: 0.9651814063769718
#
#  Model 54done.	 CV RMSE: 0.9443453140600891
#
#  Model 55done.	 CV RMSE: 0.9144775324381104
#
#  Model 56done.	 CV RMSE: 0.8846843721165369
#
#  Model 57done.	 CV RMSE: 1.0917078488545393
#
#  Model 58done.	 CV RMSE: 1.0241392149381991
#
#  Model 59done.	 CV RMSE: 0.9477498753213199
#
#  Model 60done.	 CV RMSE: 0.8906880317809146
# model_All_1.0
#
#  Model 1done.	 CV RMSE: 0.8965930168718794
#
#  Model 2done.	 CV RMSE: 0.8940518268819455
#
#  Model 3done.	 CV RMSE: 0.8916552558058218
#
#  Model 4done.	 CV RMSE: 0.8847667271326793
#
#  Model 5done.	 CV RMSE: 0.9001734990867389
#
#  Model 6done.	 CV RMSE: 0.898615826187318
#
#  Model 7done.	 CV RMSE: 0.8932535936850678
#
#  Model 8done.	 CV RMSE: 0.8770507401362012
#
#  Model 9done.	 CV RMSE: 0.925733690276104
#
#  Model 10done.	 CV RMSE: 0.9225957775465529
#
#  Model 11done.	 CV RMSE: 0.9086404325343289
#
#  Model 12done.	 CV RMSE: 0.8772750261696114
#
#  Model 13done.	 CV RMSE: 0.8955203560222006
#
#  Model 14done.	 CV RMSE: 0.8939076981690082
#
#  Model 15done.	 CV RMSE: 0.8915736731288368
#
#  Model 16done.	 CV RMSE: 0.8837982150635043
#
#  Model 17done.	 CV RMSE: 0.9021336240059914
#
#  Model 18done.	 CV RMSE: 0.9002282702332952
#
#  Model 19done.	 CV RMSE: 0.8929983972095661
#
#  Model 20done.	 CV RMSE: 0.8764321345933915
#
#  Model 21done.	 CV RMSE: 0.9294040102443302
#
#  Model 22done.	 CV RMSE: 0.9258746670141849
#
#  Model 23done.	 CV RMSE: 0.9082911085828937
#
#  Model 24done.	 CV RMSE: 0.8765443243732587
#
#  Model 25done.	 CV RMSE: 0.8953359461814347
#
#  Model 26done.	 CV RMSE: 0.8938579404013578
#
#  Model 27done.	 CV RMSE: 0.8914598843687017
#
#  Model 28done.	 CV RMSE: 0.8812537561163515
#
#  Model 29done.	 CV RMSE: 0.9042206184943974
#
#  Model 30done.	 CV RMSE: 0.9021439351169197
#
#  Model 31done.	 CV RMSE: 0.8934025149334189
#
#  Model 32done.	 CV RMSE: 0.8761631421614878
#
#  Model 33done.	 CV RMSE: 0.9327540560542561
#
#  Model 34done.	 CV RMSE: 0.9285419408231099
#
#  Model 35done.	 CV RMSE: 0.9090772385134692
#
#  Model 36done.	 CV RMSE: 0.876602460147156
#
#  Model 37done.	 CV RMSE: 0.895338429274122
#
#  Model 38done.	 CV RMSE: 0.8939516897863492
#
#  Model 39done.	 CV RMSE: 0.891439170792829
#
#  Model 40done.	 CV RMSE: 0.8806185140247815
#
#  Model 41done.	 CV RMSE: 0.9066960464667754
#
#  Model 42done.	 CV RMSE: 0.904133962119791
#
#  Model 43done.	 CV RMSE: 0.8937976899697143
#
#  Model 44done.	 CV RMSE: 0.8759980060118133
#
#  Model 45done.	 CV RMSE: 0.9378069557905041
#
#  Model 46done.	 CV RMSE: 0.9320807441282368
#
#  Model 47done.	 CV RMSE: 0.90940944849051
#
#  Model 48done.	 CV RMSE: 0.8766078285199765
#
#  Model 49done.	 CV RMSE: 0.8950114371157393
#
#  Model 50done.	 CV RMSE: 0.8936306242612952
#
#  Model 51done.	 CV RMSE: 0.8911526912410348
#
#  Model 52done.	 CV RMSE: 0.8804461835959968
#
#  Model 53done.	 CV RMSE: 0.9094402289574639
#
#  Model 54done.	 CV RMSE: 0.9063201764810699
#
#  Model 55done.	 CV RMSE: 0.8941268684305137
#
#  Model 56done.	 CV RMSE: 0.875836691458815
#
#  Model 57done.	 CV RMSE: 0.941944998914982
#
#  Model 58done.	 CV RMSE: 0.9347918940907257
#
#  Model 59done.	 CV RMSE: 0.9096183963148463
#
#  Model 60done.	 CV RMSE: 0.8765905388626873

# %%
#check best RMSE
m = {}
mi = 10.0

for key in add_info_model.keys():
    for k2 in add_info_model[key].keys():
        if add_info_model[key][k2]["cv_rmse"] <= mi:
            mi = add_info_model[key][k2]["cv_rmse"]
            m[add_info_model[key][k2]["cv_rmse"]] = key+"_"+k2
        
        
print("Best model: ",m[mi],"\t","best cv error",mi)
# Out:
# Best model:  model_All_1.0_model_seq_ 56_150_4_1.0 	 best cv error 0.875836691458815

# %%
pickle.dump(add_info_model,open("./add_info_model","wb"))

# %% [markdown]
# #### increasing hyperspace, reducing iterations to 100

# %%
###store function return
#trainX, testX, trainY, testY = load_data_simple('./ml-1m/ratings.dat')
files = (('./ml-1m/ratings.dat'),('./ml-1m/users.dat'),('./ml-1m/movies.dat'))
add_info_model_morekreg = subsample_user_item(files,model_type = "side_info")
#pickle object for later use
# Out:
# /home/som/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:11: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   # This is added back by InteractiveShellApp.init_path()
# /home/som/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   del sys.path[0]
# model_All_0.2
#
#  Model 1done.	 CV RMSE: 1.828518510476075
#
#  Model 2done.	 CV RMSE: 1.4386607472110768
#
#  Model 3done.	 CV RMSE: 1.1671672998722333
#
#  Model 4done.	 CV RMSE: 1.001282230148569
#
#  Model 5done.	 CV RMSE: 0.9232263636185501
#
#  Model 6done.	 CV RMSE: 1.7632220624881716
#
#  Model 7done.	 CV RMSE: 1.6110061000171694
#
#  Model 8done.	 CV RMSE: 1.3541147258555573
#
#  Model 9done.	 CV RMSE: 1.112966826353428
#
#  Model 10done.	 CV RMSE: 0.9440743672604938
#
#  Model 11done.	 CV RMSE: 1.799611073805364
#
#  Model 12done.	 CV RMSE: 1.6867433879321703
#
#  Model 13done.	 CV RMSE: 1.4910621561131312
#
#  Model 14done.	 CV RMSE: 1.1932522855788679
#
#  Model 15done.	 CV RMSE: 0.9538086825148885
#
#  Model 16done.	 CV RMSE: 1.9200610589945633
#
#  Model 17done.	 CV RMSE: 1.7812199339282107
#
#  Model 18done.	 CV RMSE: 1.578837664609271
#
#  Model 19done.	 CV RMSE: 1.2618391560037474
#
#  Model 20done.	 CV RMSE: 0.9688001363183516
#
#  Model 21done.	 CV RMSE: 1.8873967986618156
#
#  Model 22done.	 CV RMSE: 1.7979085615920658
#
#  Model 23done.	 CV RMSE: 1.6289194500142394
#
#  Model 24done.	 CV RMSE: 1.3172016197135925
#
#  Model 25done.	 CV RMSE: 0.9835926628459718
#
#  Model 26done.	 CV RMSE: 2.048807638080355
#
#  Model 27done.	 CV RMSE: 1.5831410730999311
#
#  Model 28done.	 CV RMSE: 1.1858738044469272
#
#  Model 29done.	 CV RMSE: 0.9995166473068534
#
#  Model 30done.	 CV RMSE: 0.9222402985578243
#
#  Model 31done.	 CV RMSE: 1.9739447927200866
#
#  Model 32done.	 CV RMSE: 1.750726793937801
#
#  Model 33done.	 CV RMSE: 1.4052362279410302
#
#  Model 34done.	 CV RMSE: 1.1189758853328342
#
#  Model 35done.	 CV RMSE: 0.9487084400251656
#
#  Model 36done.	 CV RMSE: 1.9633949409614182
#
#  Model 37done.	 CV RMSE: 1.82157600835939
#
#  Model 38done.	 CV RMSE: 1.5624657666228197
#
#  Model 39done.	 CV RMSE: 1.2052248120449198
#
#  Model 40done.	 CV RMSE: 0.9580667822902386
#
#  Model 41done.	 CV RMSE: 2.0464377803877145
#
#  Model 42done.	 CV RMSE: 1.9103999140901688
#
#  Model 43done.	 CV RMSE: 1.6503291261106274
#
#  Model 44done.	 CV RMSE: 1.276131721235627
#
#  Model 45done.	 CV RMSE: 0.9760424461476711
#
#  Model 46done.	 CV RMSE: 2.024203616185445
#
#  Model 47done.	 CV RMSE: 1.918842960582742
#
#  Model 48done.	 CV RMSE: 1.7035362905433242
#
#  Model 49done.	 CV RMSE: 1.3319024099665735
#
#  Model 50done.	 CV RMSE: 0.9921994837772911
#
#  Model 51done.	 CV RMSE: 2.246433500431337
#
#  Model 52done.	 CV RMSE: 1.7202576811258026
#
#  Model 53done.	 CV RMSE: 1.196273748309315
#
#  Model 54done.	 CV RMSE: 0.9974215691030927
#
#  Model 55done.	 CV RMSE: 0.9224865371773597
#
#  Model 56done.	 CV RMSE: 2.146013702307407
#
#  Model 57done.	 CV RMSE: 1.856924367868487
#
#  Model 58done.	 CV RMSE: 1.4410835374371296
#
#  Model 59done.	 CV RMSE: 1.1224157929518983
#
#  Model 60done.	 CV RMSE: 0.9509846380038579
#
#  Model 61done.	 CV RMSE: 2.102295171085625
#
#  Model 62done.	 CV RMSE: 1.9299557302896646
#
#  Model 63done.	 CV RMSE: 1.608053538248775
#
#  Model 64done.	 CV RMSE: 1.2126374561458895
#
#  Model 65done.	 CV RMSE: 0.9612516724710357
#
#  Model 66done.	 CV RMSE: 2.1450508809609783
#
#  Model 67done.	 CV RMSE: 1.9961430292057973
#
#  Model 68done.	 CV RMSE: 1.70242768470006
#
#  Model 69done.	 CV RMSE: 1.2842417705704579
#
#  Model 70done.	 CV RMSE: 0.9819564751557253
#
#  Model 71done.	 CV RMSE: 2.1258501085394714
#
#  Model 72done.	 CV RMSE: 2.0134424092045022
#
#  Model 73done.	 CV RMSE: 1.7568113538459458
#
#  Model 74done.	 CV RMSE: 1.3401762666866006
#
#  Model 75done.	 CV RMSE: 0.9987679334297942
# model_All_0.4
#
#  Model 1done.	 CV RMSE: 1.1814304118791243
#
#  Model 2done.	 CV RMSE: 1.0135425439538857
#
#  Model 3done.	 CV RMSE: 0.9635645130315242
#
#  Model 4done.	 CV RMSE: 0.9196462180126559
#
#  Model 5done.	 CV RMSE: 0.8965510738944701
#
#  Model 6done.	 CV RMSE: 1.2772643877041392
#
#  Model 7done.	 CV RMSE: 1.2049259235528813
#
#  Model 8done.	 CV RMSE: 1.0983909806070062
#
#  Model 9done.	 CV RMSE: 0.9717953205653035
#
#  Model 10done.	 CV RMSE: 0.8953939850685436
#
#  Model 11done.	 CV RMSE: 1.3388518197615655
#
#  Model 12done.	 CV RMSE: 1.2992705848027046
#
#  Model 13done.	 CV RMSE: 1.190289183782573
#
#  Model 14done.	 CV RMSE: 1.0259664824582266
#
#  Model 15done.	 CV RMSE: 0.8995820192713342
#
#  Model 16done.	 CV RMSE: 1.4433887039614948
#
#  Model 17done.	 CV RMSE: 1.404327202651724
#
#  Model 18done.	 CV RMSE: 1.280960867030044
#
#  Model 19done.	 CV RMSE: 1.082589360699189
#
#  Model 20done.	 CV RMSE: 0.9106148088388857
#
#  Model 21done.	 CV RMSE: 1.5199478545756935
#
#  Model 22done.	 CV RMSE: 1.4854925820446498
#
#  Model 23done.	 CV RMSE: 1.360138186059194
#
#  Model 24done.	 CV RMSE: 1.1311792994672312
#
#  Model 25done.	 CV RMSE: 0.9218115555290657
#
#  Model 26done.	 CV RMSE: 1.1835358357207681
#
#  Model 27done.	 CV RMSE: 1.0299161688195488
#
#  Model 28done.	 CV RMSE: 0.9642393685264145
#
#  Model 29done.	 CV RMSE: 0.9180152423002934
#
#  Model 30done.	 CV RMSE: 0.89653153210241
#
#  Model 31done.	 CV RMSE: 1.3428241790764381
#
#  Model 32done.	 CV RMSE: 1.2696495993945813
#
#  Model 33done.	 CV RMSE: 1.120471668918472
#
#  Model 34done.	 CV RMSE: 0.9749719938725112
#
#  Model 35done.	 CV RMSE: 0.8969712926291381
#
#  Model 36done.	 CV RMSE: 1.429508045280193
#
#  Model 37done.	 CV RMSE: 1.3806325764844563
#
#  Model 38done.	 CV RMSE: 1.2271266874813
#
#  Model 39done.	 CV RMSE: 1.0298125898337747
#
#  Model 40done.	 CV RMSE: 0.900715095547021
#
#  Model 41done.	 CV RMSE: 1.530164009995049
#
#  Model 42done.	 CV RMSE: 1.4768922328905614
#
#  Model 43done.	 CV RMSE: 1.3245201203157746
#
#  Model 44done.	 CV RMSE: 1.0890539953703253
#
#  Model 45done.	 CV RMSE: 0.9127633383249036
#
#  Model 46done.	 CV RMSE: 1.630768117530939
#
#  Model 47done.	 CV RMSE: 1.5807731021236586
#
#  Model 48done.	 CV RMSE: 1.4137013058718886
#
#  Model 49done.	 CV RMSE: 1.1409706783877185
#
#  Model 50done.	 CV RMSE: 0.9251003727240984
#
#  Model 51done.	 CV RMSE: 1.1799728611771036
#
#  Model 52done.	 CV RMSE: 1.0361801250991087
#
#  Model 53done.	 CV RMSE: 0.9687155629949084
#
#  Model 54done.	 CV RMSE: 0.918216171312493
#
#  Model 55done.	 CV RMSE: 0.8965219235897418
#
#  Model 56done.	 CV RMSE: 1.4002019229942788
#
#  Model 57done.	 CV RMSE: 1.3203027862233425
#
#  Model 58done.	 CV RMSE: 1.1337757006140858
#
#  Model 59done.	 CV RMSE: 0.9770732276957846
#
#  Model 60done.	 CV RMSE: 0.8981544616171326
#
#  Model 61done.	 CV RMSE: 1.5069449114387392
#
#  Model 62done.	 CV RMSE: 1.4446202973781057
#
#  Model 63done.	 CV RMSE: 1.2508731203408021
#
#  Model 64done.	 CV RMSE: 1.0331663707461105
#
#  Model 65done.	 CV RMSE: 0.9019821111184826
#
#  Model 66done.	 CV RMSE: 1.6014058368347153
#
#  Model 67done.	 CV RMSE: 1.5343805855406685
#
#  Model 68done.	 CV RMSE: 1.3581627480646983
#
#  Model 69done.	 CV RMSE: 1.0938457648280022
#
#  Model 70done.	 CV RMSE: 0.9143452639999138
#
#  Model 71done.	 CV RMSE: 1.7200393204368976
#
#  Model 72done.	 CV RMSE: 1.6574023537572926
#
#  Model 73done.	 CV RMSE: 1.4521015087877787
#
#  Model 74done.	 CV RMSE: 1.146770652082971
#
#  Model 75done.	 CV RMSE: 0.9274730527475717
# model_All_0.6000000000000001
#
#  Model 1done.	 CV RMSE: 0.9541779643890471
#
#  Model 2done.	 CV RMSE: 0.9360149686680805
#
#  Model 3done.	 CV RMSE: 0.9207109815265663
#
#  Model 4done.	 CV RMSE: 0.9013338857817955
#
#  Model 5done.	 CV RMSE: 0.8878699454817528
#
#  Model 6done.	 CV RMSE: 1.0307126575752008
#
#  Model 7done.	 CV RMSE: 1.019280193993145
#
#  Model 8done.	 CV RMSE: 0.9767184928282947
#
#  Model 9done.	 CV RMSE: 0.92063105974924
#
#  Model 10done.	 CV RMSE: 0.8768081311449032
#
#  Model 11done.	 CV RMSE: 1.1553073961753029
#
#  Model 12done.	 CV RMSE: 1.1381471376741579
#
#  Model 13done.	 CV RMSE: 1.0561270925129955
#
#  Model 14done.	 CV RMSE: 0.9552521112123651
#
#  Model 15done.	 CV RMSE: 0.8783990926152416
#
#  Model 16done.	 CV RMSE: 1.227095548003166
#
#  Model 17done.	 CV RMSE: 1.207495933391471
#
#  Model 18done.	 CV RMSE: 1.123262295062058
#
#  Model 19done.	 CV RMSE: 0.9938883167737598
#
#  Model 20done.	 CV RMSE: 0.8854278192034959
#
#  Model 21done.	 CV RMSE: 1.2834337658319381
#
#  Model 22done.	 CV RMSE: 1.2673415938181494
#
#  Model 23done.	 CV RMSE: 1.185662148170057
#
#  Model 24done.	 CV RMSE: 1.0322697916588521
#
#  Model 25done.	 CV RMSE: 0.8912171686292002
#
#  Model 26done.	 CV RMSE: 0.9540747466708682
#
#  Model 27done.	 CV RMSE: 0.942706121580551
#
#  Model 28done.	 CV RMSE: 0.9204387702244674
#
#  Model 29done.	 CV RMSE: 0.9010469112382887
#
#  Model 30done.	 CV RMSE: 0.8877178147457985
#
#  Model 31done.	 CV RMSE: 1.0605396852622184
#
#  Model 32done.	 CV RMSE: 1.0403632842926855
#
#  Model 33done.	 CV RMSE: 0.988293186883692
#  Model 34done.	 CV RMSE: 0.9208305950247402
#
#  Model 35done.	 CV RMSE: 0.8763600291094793
#
#  Model 36done.	 CV RMSE: 1.2277646414314705
#
#  Model 37done.	 CV RMSE: 1.2005028852559152
#
#  Model 38done.	 CV RMSE: 1.0774396458870727
#
#  Model 39done.	 CV RMSE: 0.9575723024434802
#
#  Model 40done.	 CV RMSE: 0.8784657676046138
#
#  Model 41done.	 CV RMSE: 1.2931613730036682
#
#  Model 42done.	 CV RMSE: 1.2591099167275233
#
#  Model 43done.	 CV RMSE: 1.145075185874487
#
#  Model 44done.	 CV RMSE: 0.9970978159998808
#
#  Model 45done.	 CV RMSE: 0.886021343528304
#
#  Model 46done.	 CV RMSE: 1.3572452554228787
#
#  Model 47done.	 CV RMSE: 1.3331622126909075
#
#  Model 48done.	 CV RMSE: 1.2204559167821944
#
#  Model 49done.	 CV RMSE: 1.0386723690200996
#
#  Model 50done.	 CV RMSE: 0.892821102000648
#
#  Model 51done.	 CV RMSE: 0.9933170291877568
#
#  Model 52done.	 CV RMSE: 0.9524353837299722
#
#  Model 53done.	 CV RMSE: 0.9185540284138387
#
#  Model 54done.	 CV RMSE: 0.901269490767689
#
#  Model 55done.	 CV RMSE: 0.8875673102712153
#
#  Model 56done.	 CV RMSE: 1.0883584446294288
#
#  Model 57done.	 CV RMSE: 1.0618465247529818
#
#  Model 58done.	 CV RMSE: 0.9957888573917333
#
#  Model 59done.	 CV RMSE: 0.9210659879345363
#
#  Model 60done.	 CV RMSE: 0.8761317019721274
#
#  Model 61done.	 CV RMSE: 1.3023793124989196
#
#  Model 62done.	 CV RMSE: 1.2568692745627306
#
#  Model 63done.	 CV RMSE: 1.0948992031409213
#
#  Model 64done.	 CV RMSE: 0.9584880108375936
#
#  Model 65done.	 CV RMSE: 0.8786582367034383
#
#  Model 66done.	 CV RMSE: 1.3450814505080433
#
#  Model 67done.	 CV RMSE: 1.3007488460184262
#
#  Model 68done.	 CV RMSE: 1.164709994278783
#
#  Model 69done.	 CV RMSE: 0.9994559455048933
#
#  Model 70done.	 CV RMSE: 0.8863074525436191
#
#  Model 71done.	 CV RMSE: 1.411456078374469
#
#  Model 72done.	 CV RMSE: 1.3786682555122753
#
#  Model 73done.	 CV RMSE: 1.2451939259687372
#
#  Model 74done.	 CV RMSE: 1.0430610457735165
#
#  Model 75done.	 CV RMSE: 0.8942530016382144
# model_All_0.8
#
#  Model 1done.	 CV RMSE: 0.9117964499731309
#
#  Model 2done.	 CV RMSE: 0.9072086249233775
#
#  Model 3done.	 CV RMSE: 0.8972132461730985
#
#  Model 4done.	 CV RMSE: 0.8899943484007199
#
#  Model 5done.	 CV RMSE: 0.8816542698115274
#
#  Model 6done.	 CV RMSE: 0.944885927370515
#
#  Model 7done.	 CV RMSE: 0.9386604631928349
#
#  Model 8done.	 CV RMSE: 0.9240570054404084
#
#  Model 9done.	 CV RMSE: 0.8946197229021903
#
#  Model 10done.	 CV RMSE: 0.8657171243915159
#
#  Model 11done.	 CV RMSE: 1.0315581385535226
#
#  Model 12done.	 CV RMSE: 1.015366682216903
#
#  Model 13done.	 CV RMSE: 0.9778969632879491
#
#  Model 14done.	 CV RMSE: 0.919470168990509
#
#  Model 15done.	 CV RMSE: 0.8651896119027682
#
#  Model 16done.	 CV RMSE: 1.0970612847905172
#
#  Model 17done.	 CV RMSE: 1.0880751646755336
#
#  Model 18done.	 CV RMSE: 1.0361213478977347
#
#  Model 19done.	 CV RMSE: 0.9478860338320095
#
#  Model 20done.	 CV RMSE: 0.8675193785321713
#
#  Model 21done.	 CV RMSE: 1.1584502046645442
#
#  Model 22done.	 CV RMSE: 1.150009244046083
#
#  Model 23done.	 CV RMSE: 1.0944184299076227
#
#  Model 24done.	 CV RMSE: 0.9787313280175877
#
#  Model 25done.	 CV RMSE: 0.871267747264087
#
#  Model 26done.	 CV RMSE: 0.9225483090213074
#
#  Model 27done.	 CV RMSE: 0.9137960525216852
#
#  Model 28done.	 CV RMSE: 0.8950546772765127
#
#  Model 29done.	 CV RMSE: 0.8886997903095049
#
#  Model 30done.	 CV RMSE: 0.8808043031713014
#
#  Model 31done.	 CV RMSE: 0.9538832393573096
#
#  Model 32done.	 CV RMSE: 0.9464870214271534
#
#  Model 33done.	 CV RMSE: 0.9277442595073738
#
#  Model 34done.	 CV RMSE: 0.8946522994659409
#
#  Model 35done.	 CV RMSE: 0.8651922419298169
#
#  Model 36done.	 CV RMSE: 1.059901226488088
#
#  Model 37done.	 CV RMSE: 1.0384188536295018
#
#  Model 38done.	 CV RMSE: 0.9887399467270142
#
#  Model 39done.	 CV RMSE: 0.9208594465985359
#
#  Model 40done.	 CV RMSE: 0.864333187868885
#
#  Model 41done.	 CV RMSE: 1.1470785382745743
#
#  Model 42done.	 CV RMSE: 1.1293382350516599
#
#  Model 43done.	 CV RMSE: 1.0533807393089611
#
#  Model 44done.	 CV RMSE: 0.9501976610480272
#
#  Model 45done.	 CV RMSE: 0.867187848939281
#
#  Model 46done.	 CV RMSE: 1.2210772488247519
#
#  Model 47done.	 CV RMSE: 1.2075749594941143
#
#  Model 48done.	 CV RMSE: 1.124979736951218
#
#  Model 49done.	 CV RMSE: 0.9826191557347349
#
#  Model 50done.	 CV RMSE: 0.8718951901736807
#
#  Model 51done.	 CV RMSE: 0.9429900070107259
#
#  Model 52done.	 CV RMSE: 0.9169196776041798
#
#  Model 53done.	 CV RMSE: 0.8944470092798583
#
#  Model 54done.	 CV RMSE: 0.8866568176900921
#
#  Model 55done.	 CV RMSE: 0.8802196416556384
#
#  Model 56done.	 CV RMSE: 0.9618203807106753
#
#  Model 57done.	 CV RMSE: 0.9533921546004691
#
#  Model 58done.	 CV RMSE: 0.929165093346552
#
#  Model 59done.	 CV RMSE: 0.8948906300533134
#
#  Model 60done.	 CV RMSE: 0.8649382288718617
#
#  Model 61done.	 CV RMSE: 1.0852116926943607
#
#  Model 62done.	 CV RMSE: 1.0558234729421
#
#  Model 63done.	 CV RMSE: 0.9967282983520217
#
#  Model 64done.	 CV RMSE: 0.9198873868766014
#
#  Model 65done.	 CV RMSE: 0.8638065697204763
#
#  Model 66done.	 CV RMSE: 1.187918906538929
#
#  Model 67done.	 CV RMSE: 1.157119277607825
#
#  Model 68done.	 CV RMSE: 1.0630878389149787
#
#  Model 69done.	 CV RMSE: 0.9514173536495664
#
#  Model 70done.	 CV RMSE: 0.8669873413477434
#
#  Model 71done.	 CV RMSE: 1.273983930371847
#
#  Model 72done.	 CV RMSE: 1.255126188296049
#
#  Model 73done.	 CV RMSE: 1.1463442052691901
#
#  Model 74done.	 CV RMSE: 0.9856551286916547
#
#  Model 75done.	 CV RMSE: 0.8726214276239354
# model_All_1.0
#
#  Model 1done.	 CV RMSE: 0.8990934524544776
#
#  Model 2done.	 CV RMSE: 0.8935584757429913
#
#  Model 3done.	 CV RMSE: 0.8889745630089346
#
#  Model 4done.	 CV RMSE: 0.8827785165909724
#
#  Model 5done.	 CV RMSE: 0.8777565165838767
#
#  Model 6done.	 CV RMSE: 0.9089821378400138
#
#  Model 7done.	 CV RMSE: 0.9059400561966298
#
#  Model 8done.	 CV RMSE: 0.898022319513233
#
#  Model 9done.	 CV RMSE: 0.8761272145941645
#
#  Model 10done.	 CV RMSE: 0.8592083095360415
#
#  Model 11done.	 CV RMSE: 0.9552594367998636
#
#  Model 12done.	 CV RMSE: 0.9529854184498441
#
#  Model 13done.	 CV RMSE: 0.934141284348655
#
#  Model 14done.	 CV RMSE: 0.892638806499179
#
#  Model 15done.	 CV RMSE: 0.8556733170477341
#
#  Model 16done.	 CV RMSE: 1.0166569542781299
#
#  Model 17done.	 CV RMSE: 1.0115781005253022
#
#  Model 18done.	 CV RMSE: 0.9773949859052492
#
#  Model 19done.	 CV RMSE: 0.9139199690936155
#
#  Model 20done.	 CV RMSE: 0.855615201950237
#
#  Model 21done.	 CV RMSE: 1.0665501017875656
#
#  Model 22done.	 CV RMSE: 1.058082006481669
#
#  Model 23done.	 CV RMSE: 1.0200906097815192
#
#  Model 24done.	 CV RMSE: 0.9374571865371244
#
#  Model 25done.	 CV RMSE: 0.8586496438956541
#
#  Model 26done.	 CV RMSE: 0.8957202039131208
#
#  Model 27done.	 CV RMSE: 0.8927212094543231
#
#  Model 28done.	 CV RMSE: 0.886719370469414
#
#  Model 29done.	 CV RMSE: 0.8820837590465608
#
#  Model 30done.	 CV RMSE: 0.8768451012558234
#
#  Model 31done.	 CV RMSE: 0.9123150034884777
#
#  Model 32done.	 CV RMSE: 0.9091585082249455
#
#  Model 33done.	 CV RMSE: 0.8982115918629914
#
#  Model 34done.	 CV RMSE: 0.8750257511259003
#
#  Model 35done.	 CV RMSE: 0.8586812769366942
#
#  Model 36done.	 CV RMSE: 0.971387771729876
#
#  Model 37done.	 CV RMSE: 0.967167511460289
#
#  Model 38done.	 CV RMSE: 0.9397929733084434
#
#  Model 39done.	 CV RMSE: 0.8918208361766361
#
#  Model 40done.	 CV RMSE: 0.8546046899192654
#
#  Model 41done.	 CV RMSE: 1.0401753034968435
#
#  Model 42done.	 CV RMSE: 1.032515955235692
#
#  Model 43done.	 CV RMSE: 0.9882691439818514
#
#  Model 44done.	 CV RMSE: 0.9160543193194747
#
#  Model 45done.	 CV RMSE: 0.8547110792336028
#
#  Model 46done.	 CV RMSE: 1.1094670677377125
#
#  Model 47done.	 CV RMSE: 1.0924641452989925
#
#  Model 48done.	 CV RMSE: 1.0374878564279713
#
#  Model 49done.	 CV RMSE: 0.9415556651015963
#
#  Model 50done.	 CV RMSE: 0.8588994788161071
#
#  Model 51done.	 CV RMSE: 0.8951143004059972
#
#  Model 52done.	 CV RMSE: 0.8920147247148048
#
#  Model 53done.	 CV RMSE: 0.8854958886008724
#
#  Model 54done.	 CV RMSE: 0.8812175072716448
#
#  Model 55done.	 CV RMSE: 0.8760157841378942
#
#  Model 56done.	 CV RMSE: 0.9162436448982019
#
#  Model 57done.	 CV RMSE: 0.9126855164204419
#
#  Model 58done.	 CV RMSE: 0.8994444417960674
#
#  Model 59done.	 CV RMSE: 0.8749437083663593
#
#  Model 60done.	 CV RMSE: 0.858435332806679
#
#  Model 61done.	 CV RMSE: 0.9830211638441352
#
#  Model 62done.	 CV RMSE: 0.9769662135098712
#
#  Model 63done.	 CV RMSE: 0.942835131005695
#
#  Model 64done.	 CV RMSE: 0.8910929796592351
#
#  Model 65done.	 CV RMSE: 0.8540233748897804
#
#  Model 66done.	 CV RMSE: 1.0604534782128898
#  Model 67done.	 CV RMSE: 1.0493606698805287
#
#  Model 68done.	 CV RMSE: 0.996720615080953
#
#  Model 69done.	 CV RMSE: 0.916527486007083
#
#  Model 70done.	 CV RMSE: 0.8540838671576749
#
#  Model 71done.	 CV RMSE: 1.1357729575298818
#
#  Model 72done.	 CV RMSE: 1.1186259728543406
#
#  Model 73done.	 CV RMSE: 1.0518895605631233
#
#  Model 74done.	 CV RMSE: 0.9437555998169164
#
#  Model 75done.	 CV RMSE: 0.8590930371564496

# %%
#check best RMSE
m = {}
mi = 10.0

for key in add_info_model_morekreg.keys():
    for k2 in add_info_model_morekreg[key].keys():
        if add_info_model_morekreg[key][k2]["cv_rmse"] <= mi:
            mi = add_info_model_morekreg[key][k2]["cv_rmse"]
            m[add_info_model_morekreg[key][k2]["cv_rmse"]] = key+"_"+k2
        
        
print("Best model: ",m[mi],"\t","best cv error",mi)
# Out:
# Best model:  model_All_1.0_model_seq_ 65_100_8_10.0 	 best cv error 0.8540233748897804

# %%
pickle.dump(add_info_model_morekreg,open("./add_info_model_morekreg","wb"))
